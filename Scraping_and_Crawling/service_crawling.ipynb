# %% [markdown]
# # 비정형 데이터 활용하기

# %% [markdown]
# # Scraping (BeautifulSoup)
# > BeautifulSoup 라이브러리에 대한 이해와 실습.
#
# > 당근마켓 웹페이지에서 각 태그에 해당하는 내용 가져오기.
#
# > 기상청 기상정보를 가져와 dataframe으로 정리하고 csv 파일 생성.
#
# > 실습 3. Totally Normal Gifts 웹페이지의 내용을 dataframe으로 정리하고 csv 파일 생성.

# %% [markdown]
# ## BeautifulSoup
#
# - HTML, XML 파일을 읽어들일 때 사용한다.
# - 주로 bs4를 설치하고 사용하고 findAll 함수를 사용할 수 있다.
# - children(자식), descendants(자손) 태그의 개념을 알아야 한다.
#
#
# `<body>
#     <div>			// 모든 태그는 body 태그의 자손
#         <h1></h1>		// h1 태그는 div 태그의 자손이자 자식
#         <p></p>
#     </div>
#     <div>
#         <p>
#             <a></a>	// a 태그는 p 태그의 자손이자 자식
#         </p>
#     </div>`

# %% [markdown]
# ## 사전작업

# %%
import requests
from bs4 import BeautifulSoup

# %%
webpage = requests.get('https://www.daangn.com/hot_articles')
# webpage.text
soup = BeautifulSoup(webpage.content , 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
# <link href="https://www.daangn.com/hot_articles" rel="canonical"/>
# <title>당근마켓 중고거래 | 당신 근처의 당근마켓</title>
# <meta content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." name="description"/>
# <meta content="https://www.daangn.com/hot_articles" property="og:url"/>
# <meta content="당근마켓 중고거래 | 당신 근처의 당근마켓" property="og:title"/>
# <meta content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." property="og:description"/>
# <meta content="당근마켓" property="og:site_name"/>
# <meta content="https://www.daangn.com/images/meta/home/flea_market.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="ko_KR" property="og:locale"/>
# <meta content="1463621440622064" property="fb:app_id"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@danggeunmarket" name="twitter:site"/>
# <meta content="당근마켓 중고거래 | 당신 근처의 당근마켓" name="twitter:title"/>
# <meta content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." name="twitter:description"/>
# <meta content="https://www.daangn.com/images/meta/home/flea_market.png" name="twitter:image"/>
# <meta content="당근마켓" name="author"/>
# <meta content="8273a462d4256dc90c43fbfa8ecbe29675ede28c" name="naver-site-verification"/>
# <link href="/images/icons/shortcut_icon.png" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://d1unjqcospf8gs.cloudfront.net/favicon.ico" rel="shortcut icon" type="image/x-icon">
# <link href="https://d1unjqcospf8gs.cloudfront.net/assets/home/articles/hot-5a66164356b6257c2849e833649bd7482f5f581e017feb9f28e477ca285f9cfa.css" media="all" rel="stylesheet"/>
# <script src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base-d5f8bd2e2e6729d4f86324f85bbdb9a5c6bafeff1957b761a1187ae9c7d773b8.js"></script>
# <link href="https://fonts.googleapis.com/css2?family=Noto+Sans+KR:wght@400;700" rel="stylesheet"/>
# <link href="/images/icons/daangn_logo_192.png" rel="apple-touch-icon" sizes="192x192"/>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
#   <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#   <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#   <![endif]-->
# <meta content="authenticity_token" name="csrf-param">
# <meta content="8dIRVPMpuWpN676aK1QUpvYton2kZvPPJsPKj1ze6Q0+ymKeVmKIlUWIwe2pHCnPNXWnxEXAi4LHxyCcYpgmyw==" name="csrf-token">
# <script>
#     window.fbAsyncInit = function() {
#       FB.init({
#         appId      : '1463621440622064',
#         xfbml      : true,
#         version    : 'v2.4'
#       });
#     };
#
#     (function(d, s, id){
#       var js, fjs = d.getElementsByTagName(s)[0];
#       if (d.getElementById(id)) {return;}
#       js = d.createElement(s); js.id = id;
#       js.src = "//connect.facebook.net/en_US/sdk.js";
#       fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
#   </script>
# <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#               (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#             m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-64551386-2', 'auto');
#      ga('set', 'dimension2', 'false');  ga('send', 'pageview'); </script>
# <!-- Facebook Pixel Code -->
# <script>
#       !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#               n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#         n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#         t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#               document,'script','//connect.facebook.net/en_US/fbevents.js');
#
#       fbq('init', '992961397411651');
#       fbq('track', "PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=992961397411651&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-PJSK4QL');</script>
# <!-- End Google Tag Manager -->
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "name": "당근마켓",
#   "url": "https://www.daangn.com",
#   "sameAs": [
#     "https://www.facebook.com/daangn",
#     "https://blog.naver.com/daangn",
#     "https://www.youtube.com/channel/UC8tsBsQBuF7QybxgLmStihA",
#     "https://twitter.com/danggeunmarket",
#     "https://www.instagram.com/daangnmarket",
#     "https://itunes.apple.com/kr/app/id1018769995",
#     "https://play.google.com/store/apps/details?id=com.towneers.www"
#   ]
# }
# </script>
# </meta></meta></link></head>
# <body class="hoian-kr">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJSK4QL" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header id="fixed-bar">
# <div id="fixed-bar-wrap">
# <h1 id="fixed-bar-logo-title">
# <a href="https://www.daangn.com/">
# <span class="sr-only">당근마켓</span>
# <img alt="당근마켓" class="fixed-logo" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg"/>
# </a> </h1>
# <section id="fixed-bar-search">
# <div class="search-input-wrap">
# <span class="sr-only">검색</span>
# <input class="fixed-search-input" id="header-search-input" name="header-search-input" placeholder="동네 이름, 물품명 등을 검색해보세요!" type="text"/>
# <button id="header-search-button">
# <img alt="Search" class="fixed-search-icon" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/search-icon-7008edd4f9aaa32188f55e65258f1c1905d7a9d1a3ca2a07ae809b5535380f14.svg"/>
# </button>
# </div>
# </section>
# <section id="fixed-bar-download">
# <h3 class="hide">다운로드</h3>
# <a class="fixed-download-button" href="https://itunes.apple.com/kr/app/pangyojangteo/id1018769995?l=ko&amp;ls=1&amp;mt=8" id="header-download-button-ios" target="_blank">
# <img alt="App Store" class="fixed-apple-store" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/apple-store-3a664174124650d63cae365bc55586fc5ff27b822b1b97788fc4af77d73d00c8.svg"/>
# <div class="fixed-download-text">App Store</div>
# </a> <a class="fixed-download-button" href="https://play.google.com/store/apps/details?id=com.towneers.www" id="header-download-button-android" target="_blank">
# <img alt="Google Play" class="fixed-google-play" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/google-play-c9ad0fc573cd01e2b982df5de6709a3d8d7cec8d9b58a5c08db7da0b92a32a75.svg"/>
# <div class="fixed-download-text">Google Play</div>
# </a> </section>
# </div>
# </header>
# <section id="content">
# <h1 class="head-title" id="hot-articles-head-title">
#
#
#     중고거래 인기매물
#   </h1>
# <nav id="hot-articles-navigation">
# <select class="hot-articles-nav-select" id="region1" name="region1" onchange="changeRegion('r1', this.value)"><option value="">지역을 선택하세요</option><option value="서울특별시">서울특별시</option>
# <option value="부산광역시">부산광역시</option>
# <option value="대구광역시">대구광역시</option>
# <option value="인천광역시">인천광역시</option>
# <option value="광주광역시">광주광역시</option>
# <option value="대전광역시">대전광역시</option>
# <option value="울산광역시">울산광역시</option>
# <option value="세종특별자치시">세종특별자치시</option>
# <option value="경기도">경기도</option>
# <option value="강원도">강원도</option>
# <option value="충청북도">충청북도</option>
# <option value="충청남도">충청남도</option>
# <option value="전라북도">전라북도</option>
# <option value="전라남도">전라남도</option>
# <option value="경상북도">경상북도</option>
# <option value="경상남도">경상남도</option>
# <option value="제주특별자치도">제주특별자치도</option></select>
# <select class="hot-articles-nav-select" disabled="disabled" id="region2" name="region2" onchange="changeRegion('r2', this.value)"><option value="">동네를 선택하세요</option><option value="서울특별시">서울특별시</option>
# <option value="부산광역시">부산광역시</option>
# <option value="대구광역시">대구광역시</option>
# <option value="인천광역시">인천광역시</option>
# <option value="광주광역시">광주광역시</option>
# <option value="대전광역시">대전광역시</option>
# <option value="울산광역시">울산광역시</option>
# <option value="세종특별자치시">세종특별자치시</option>
# <option value="경기도">경기도</option>
# <option value="강원도">강원도</option>
# <option value="충청북도">충청북도</option>
# <option value="충청남도">충청남도</option>
# <option value="전라북도">전라북도</option>
# <option value="전라남도">전라남도</option>
# <option value="경상북도">경상북도</option>
# <option value="경상남도">경상남도</option>
# <option value="제주특별자치도">제주특별자치도</option></select>
# </nav>
# <section class="cards-wrap">
# <article class="card-top ">
# <a class="card-link " data-event-label="132070105" href="/articles/132070105">
# <div class="card-photo ">
# <img alt="위닉스10리터 제습기 급매 1만원" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/0762b109344a9b40fa99e91d02f20f6fcb3c5e3a69b3e7fd9dba4a44660b7fee.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">위닉스10리터 제습기 급매 1만원</h2>
# <div class="card-price ">
#         10,000원
#       </div>
# <div class="card-region-name">
#         대전 중구 문화1동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 21
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132137750" href="/articles/132137750">
# <div class="card-photo ">
# <img alt="캠핑, 잡템 먼저가져가면 장땡" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/07347eb8dfecbb8c78f76b7ff5fb9f442ab78075f693593a900d129dd054505a.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">캠핑, 잡템 먼저가져가면 장땡</h2>
# <div class="card-price ">
#         무료나눔
#       </div>
# <div class="card-region-name">
#         전북 전주시 완산구 효자4동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132075404" href="/articles/132075404">
# <div class="card-photo ">
# <img alt="아이폰8 화이트 64기가 판매합니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/DD19A0BE7D83B46A7763BF2691BF634E7AFC5B406CC379AEBBD628D4EEF3D88F.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이폰8 화이트 64기가 판매합니다.</h2>
# <div class="card-price ">
#         100,000원
#       </div>
# <div class="card-region-name">
#         경북 구미시 인동동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 23
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132072045" href="/articles/132072045">
# <div class="card-photo ">
# <img alt="스팸 판매합니다. " src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/FD8082154C5793C515A4EE7A042C4EAD6BDFE3183F1D60DD38E834946A9CAE2A.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스팸 판매합니다. </h2>
# <div class="card-price ">
#         10,000원
#       </div>
# <div class="card-region-name">
#         경기도 고양시 일산서구 주엽1동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132012531" href="/articles/132012531">
# <div class="card-photo ">
# <img alt="이케아 책상 가져가실분" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/41C36378AA7950B639C3724D082C7CBA7F908E55B2B62F93473ABF3A2A0152A0.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">이케아 책상 가져가실분</h2>
# <div class="card-price ">
#         1원
#       </div>
# <div class="card-region-name">
#         대구 중구 남산4동
#       </div>
# <div class="card-counts">
# <span>
#             관심 11
#           </span>
#         ∙
#         <span>
#             채팅 23
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132110036" href="/articles/132110036">
# <div class="card-photo ">
# <img alt="복합기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/65a2710ea1d6813186e8bcdfa79377b7799e4e086fdfdc67253c3cba7be6a191.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">복합기</h2>
# <div class="card-price ">
#         무료나눔
#       </div>
# <div class="card-region-name">
#         경기도 안산시 단원구 중앙동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132003228" href="/articles/132003228">
# <div class="card-photo ">
# <img alt="캠핑키친테이블(거의새거임)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/BC4239739883AEB7043E1BDD469C8B6CCEC585E8D2052C3A24E366A21D19E7A1.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">캠핑키친테이블(거의새거임)</h2>
# <div class="card-price ">
#         25,000원
#       </div>
# <div class="card-region-name">
#         부산 수영구 광안동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="131940414" href="/articles/131940414">
# <div class="card-photo ">
# <img alt="아이폰에어팟 2세대 무선(정품)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202009/a891177f8214b103c8b59c46726e9fb5e07dd309db96af10c7472905008f1734.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이폰에어팟 2세대 무선(정품)</h2>
# <div class="card-price ">
#         20,000원
#       </div>
# <div class="card-region-name">
#         부산 부산진구 전포동
#       </div>
# <div class="card-counts">
# <span>
#             관심 16
#           </span>
#         ∙
#         <span>
#             채팅 41
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132079778" href="/articles/132079778">
# <div class="card-photo ">
# <img alt="선물세트 팝니데이" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/1822DFB926594A3AAE59EF763C620335CE4A416E66D17F91A326A5BEC98DAC18.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">선물세트 팝니데이</h2>
# <div class="card-price ">
#         18,000원
#       </div>
# <div class="card-region-name">
#         부산 부산진구 범천동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132075108" href="/articles/132075108">
# <div class="card-photo ">
# <img alt="전동킥보드" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/29736013950e278648db97188693e10bd1aac8cf477a23d9fecb7e5bfa951cb3.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">전동킥보드</h2>
# <div class="card-price ">
#         10,000원
#       </div>
# <div class="card-region-name">
#         광주 서구 동천동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132055359" href="/articles/132055359">
# <div class="card-photo ">
# <img alt="타이틀 리스트 골프백" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/3ed708af47ae141446712c5b9d49aabccd34e535fa061faac1352e52e32a086b.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">타이틀 리스트 골프백</h2>
# <div class="card-price ">
#         30,000원
#       </div>
# <div class="card-region-name">
#         경기도 화성시 동탄5동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132126018" href="/articles/132126018">
# <div class="card-photo ">
# <img alt="제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/50b0fce4ea3676674dbc0a4496d346397add86d5ecd1afe7143474f3967a594d.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">제습기</h2>
# <div class="card-price ">
#         무료나눔
#       </div>
# <div class="card-region-name">
#         서울 마포구 성산동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132020602" href="/articles/132020602">
# <div class="card-photo ">
# <img alt="스피드랙 선반(새거)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/0f1cfe552292ca44dd0c9bb0ce95f7cb64d5d5fa97721b62d3bad63ab04d20d4.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스피드랙 선반(새거)</h2>
# <div class="card-price ">
#         15,000원
#       </div>
# <div class="card-region-name">
#         부산 강서구 명지동
#       </div>
# <div class="card-counts">
# <span>
#             관심 8
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132026639" href="/articles/132026639">
# <div class="card-photo ">
# <img alt="캠핑용품-해먹,릴선" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/DCC073C63206BCF1F92557D44722DAE7A8C7BA85FA6522D9846B8CBE22768C06.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">캠핑용품-해먹,릴선</h2>
# <div class="card-price ">
#         5,000원
#       </div>
# <div class="card-region-name">
#         경기도 안산시 단원구 고잔동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132109549" href="/articles/132109549">
# <div class="card-photo ">
# <img alt="아이패드 매직키보드 트랙패드 12.9인치" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/17369596B5BF0962D5D5D47370CD02BEF46DF4210AE4C87BD7CE7964D3FADB0A.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이패드 매직키보드 트랙패드 12.9인치</h2>
# <div class="card-price ">
#         100,000원
#       </div>
# <div class="card-region-name">
#         서울 마포구 용강동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132023626" href="/articles/132023626">
# <div class="card-photo ">
# <img alt="제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/59991380a1a1d06d32b0ed6bd6bab0368cbee11e28c4535fdfc61dd969b8c694.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">제습기</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         인천 미추홀구 주안5동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="131860379" href="/articles/131860379">
# <div class="card-photo ">
# <img alt="아이폰11" src="https://dnvefa72aowie.cloudfront.net/origin/article/202009/4e7f7f1a23030894c727b8d0e7018fef15b27a94d25dbac8760f9aa33a5eac37.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이폰11</h2>
# <div class="card-price ">
#         100,000원
#       </div>
# <div class="card-region-name">
#         부산 부산진구 전포동
#       </div>
# <div class="card-counts">
# <span>
#             관심 17
#           </span>
#         ∙
#         <span>
#             채팅 51
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132088403" href="/articles/132088403">
# <div class="card-photo ">
# <img alt="자전거" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/8c802021bf2c9de5836bef8537e5132d2a439ab3dcb6c15e3b79098e05c9fd44.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">자전거</h2>
# <div class="card-price ">
#         무료나눔
#       </div>
# <div class="card-region-name">
#         경기도 수원시 영통구 망포동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132139025" href="/articles/132139025">
# <div class="card-photo ">
# <img alt="딥디크 도손향수 " src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/1207089AD5F56D05FC0ED851193CF46B1F4FD5E7B203EBBD810146B33740E4BD.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">딥디크 도손향수 </h2>
# <div class="card-price ">
#         12,000원
#       </div>
# <div class="card-region-name">
#         서울 관악구 은천동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132005237" href="/articles/132005237">
# <div class="card-photo ">
# <img alt="몽클레어 야상/바람막이/경량패딩" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/470a563c748fabe64c48445d3f107b5ef8270757982680e4b440014406c5849c.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">몽클레어 야상/바람막이/경량패딩</h2>
# <div class="card-price ">
#         100,000원
#       </div>
# <div class="card-region-name">
#         서울 서초구 반포2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132054711" href="/articles/132054711">
# <div class="card-photo ">
# <img alt="미니책장 드립니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/facc94efcbf4e7c2f28c0242fed2fdc0bf8272c3a49a672794e5058b5a64752d.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">미니책장 드립니다.</h2>
# <div class="card-price ">
#         무료나눔
#       </div>
# <div class="card-region-name">
#         경기도 평택시 원평동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132049016" href="/articles/132049016">
# <div class="card-photo ">
# <img alt="제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/64f34b50237471341d923d9e8825327806756cf535aa6a8f6b6f1e7c970f00aa.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">제습기</h2>
# <div class="card-price ">
#         10,000원
#       </div>
# <div class="card-region-name">
#         경기도 광주시 오포읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132047146" href="/articles/132047146">
# <div class="card-photo ">
# <img alt="자전거 판매합니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/403f4cbb0aa42445337cacae79cc406b86eec5ea9fde51697a25e9d1c854318f.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">자전거 판매합니다</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         서울 노원구 월계3동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132049730" href="/articles/132049730">
# <div class="card-photo ">
# <img alt="LG제습기 LD-067DSR" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/faead531ace040322c68247d2764204bacb287dc36b30437f71604989fe64067.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">LG제습기 LD-067DSR</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         인천 계양구 계산동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132107086" href="/articles/132107086">
# <div class="card-photo ">
# <img alt="전기자전거" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/0b105f227adea147daaffbbe9e7bda1b1cc3629272648469a42776977d620036.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">전기자전거</h2>
# <div class="card-price ">
#         80,000원
#       </div>
# <div class="card-region-name">
#         서울 서초구 서초4동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="131957825" href="/articles/131957825">
# <div class="card-photo ">
# <img alt="위닉스 플라즈마웨이브 제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202009/09da5d1b058377d48e7b10aa3a8540fa9ac508173bbc4df0a0f77bb3d0a8b076.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">위닉스 플라즈마웨이브 제습기</h2>
# <div class="card-price ">
#         60,000원
#       </div>
# <div class="card-region-name">
#         서울 성북구 하월곡동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 28
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132108989" href="/articles/132108989">
# <div class="card-photo ">
# <img alt="미니 자전거" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/019636527e237989268227d4d9ef63606db12daef37855f152044b1dc19dd427.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">미니 자전거</h2>
# <div class="card-price ">
#         60,000원
#       </div>
# <div class="card-region-name">
#         경기도 용인시 수지구 상현동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="131993548" href="/articles/131993548">
# <div class="card-photo ">
# <img alt="콤프레샤 ,타카3종,타카심,에어줄,공구함서비스" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/41e620c83c851fcc33bc2d09ad9d5242c4b0ff83c4dce1f4a48551d1b717d431.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">콤프레샤 ,타카3종,타카심,에어줄,공구함서비스</h2>
# <div class="card-price ">
#         200,000원
#       </div>
# <div class="card-region-name">
#         광주 광산구 첨단2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="131949667" href="/articles/131949667">
# <div class="card-photo ">
# <img alt="만원에 가져가세요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202009/2671207cb37764d465376a2e0410a1c9955b75145fd89a9bdef0ae7dfbe5498d.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">만원에 가져가세요</h2>
# <div class="card-price ">
#         10,000원
#       </div>
# <div class="card-region-name">
#         충남 천안시 서북구 두정동
#       </div>
# <div class="card-counts">
# <span>
#             관심 13
#           </span>
#         ∙
#         <span>
#             채팅 33
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132075090" href="/articles/132075090">
# <div class="card-photo ">
# <img alt="전동킥보드 2대 판매합니다.(성인용)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/d57770d802f2e058c170685e8723ea17b2550f42a62aafe6f843cb4d649a9ab4.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">전동킥보드 2대 판매합니다.(성인용)</h2>
# <div class="card-price ">
#         100,000원
#       </div>
# <div class="card-region-name">
#         경기도 의왕시 삼동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132012482" href="/articles/132012482">
# <div class="card-photo ">
# <img alt="제닉스 아레나 게이밍 의자 판매합니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/729020845afd6e97237137bf1cce40ef7ad112111b6e6ccda31663e40c86dd5d.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">제닉스 아레나 게이밍 의자 판매합니다.</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         경기도 수원시 영통구 영통동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132077640" href="/articles/132077640">
# <div class="card-photo ">
# <img alt="어항무료입니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/d094bd176331f4bbdcd680e5195f8e45602ee7cba132f649d929f4781ec02b6a.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">어항무료입니다</h2>
# <div class="card-price blank-price">
#         -
#       </div>
# <div class="card-region-name">
#         인천 부평구 삼산2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="131982758" href="/articles/131982758">
# <div class="card-photo ">
# <img alt="(커피 핸드드립세트) 원두분쇄기, 커피주전자, 커피드리퍼, 커피필터" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/02f7c19acd94502d23258cbbac1903e73df95665b4516c1eb582ee515b175bf1.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">(커피 핸드드립세트) 원두분쇄기, 커피주전자, 커피드리퍼, 커피필터</h2>
# <div class="card-price ">
#         10,000원
#       </div>
# <div class="card-region-name">
#         세종시  조치원읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 12
#           </span>
#         ∙
#         <span>
#             채팅 22
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132072611" href="/articles/132072611">
# <div class="card-photo ">
# <img alt="(이전비포함) LG 디오스 김치냉장고 4도어 (405L)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/d1988cb861b5ad7d81a8460a7bf80e59be49043d20411331eb88d1e80f3f2bf2.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">(이전비포함) LG 디오스 김치냉장고 4도어 (405L)</h2>
# <div class="card-price ">
#         300,000원
#       </div>
# <div class="card-region-name">
#         서울 노원구 상계10동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132033713" href="/articles/132033713">
# <div class="card-photo ">
# <img alt="체형교정 커블와이더 의자" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/45899aaa669e9d12fc063356aed9edf9d8bab877fdd0d9f826a07f5525a2f57e.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">체형교정 커블와이더 의자</h2>
# <div class="card-price ">
#         20,000원
#       </div>
# <div class="card-region-name">
#         서울 성북구 정릉제2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132093812" href="/articles/132093812">
# <div class="card-photo ">
# <img alt="여성용 자전거" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/8DC21C98D2DBCF27E917DA99FDD46334A7896BE16A428646BB6F50C58707DE9B.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">여성용 자전거</h2>
# <div class="card-price ">
#         80,000원
#       </div>
# <div class="card-region-name">
#         서울 노원구 하계2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132068623" href="/articles/132068623">
# <div class="card-photo ">
# <img alt="울산 오토캠핑장 2박 양도" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/d598230e9eff4f43aa97dd9922381c5571f538d72cbffc8a51e076ab82b7fa46.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">울산 오토캠핑장 2박 양도</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         울산 남구 삼산동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132121776" href="/articles/132121776">
# <div class="card-photo ">
# <img alt="아이패드 6세대 128g + 애플펜슬 + 케이스" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/14F99C54567706F08A190FA912A036A174EF5BDBF2B8C6767962497F32821A98.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이패드 6세대 128g + 애플펜슬 + 케이스</h2>
# <div class="card-price ">
#         600,000원
#       </div>
# <div class="card-region-name">
#         서울 성북구 정릉동
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132044830" href="/articles/132044830">
# <div class="card-photo ">
# <img alt="원터치 텐트 및 침낭 판매 합니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/9d43f9479ab0e05135404755049ef4112e21928410d90717d601ead8604755bf.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">원터치 텐트 및 침낭 판매 합니다.</h2>
# <div class="card-price ">
#         20,000원
#       </div>
# <div class="card-region-name">
#         경남 창원시 성산구 반림동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132113930" href="/articles/132113930">
# <div class="card-photo ">
# <img alt="냉장고 미사용 제품" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/4542a949f4ddcc67507bd88641756533a5f2855f3d6d6f25834e1e9fae6add37.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">냉장고 미사용 제품</h2>
# <div class="card-price ">
#         150,000원
#       </div>
# <div class="card-region-name">
#         전북 전주시 완산구 효자동2가
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="131993146" href="/articles/131993146">
# <div class="card-photo ">
# <img alt="각도절단기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/287233166a6ebfd23d59ac500e5e00e5c784835f5a68596b8b04f8b2927320fe.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">각도절단기</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         광주 광산구 첨단2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132087479" href="/articles/132087479">
# <div class="card-photo ">
# <img alt="자전거 판매" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/28ff7b68fd04928ac0d4b8f1f085dbd9f1ce932074b2508444945188a31f2a26.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">자전거 판매</h2>
# <div class="card-price ">
#         20,000원
#       </div>
# <div class="card-region-name">
#         경기도 화성시 동탄1동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132007088" href="/articles/132007088">
# <div class="card-photo ">
# <img alt="알톤 자전거 팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/f29bc765ca0cede4af5a8033b3e02c61b067a23d8d79756253a202330a5a3446.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">알톤 자전거 팔아요</h2>
# <div class="card-price ">
#         30,000원
#       </div>
# <div class="card-region-name">
#         경기도 용인시 수지구 동천동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 14
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132069818" href="/articles/132069818">
# <div class="card-photo ">
# <img alt="화분 무료드림합니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/1ed6bba060f54e42a9f8b80b0143b668cb2d8cb815eb0da7ee9f42e2e6054ad6.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">화분 무료드림합니다</h2>
# <div class="card-price ">
#         무료나눔
#       </div>
# <div class="card-region-name">
#         서울 강동구 둔촌제2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132019047" href="/articles/132019047">
# <div class="card-photo ">
# <img alt="숀리 엑스바이크, 실내자전거 판매" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/B2FF1C7845949EA2EDF817F43D63F411871A8E38A94121630EB045FDEAE78307.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">숀리 엑스바이크, 실내자전거 판매</h2>
# <div class="card-price ">
#         70,000원
#       </div>
# <div class="card-region-name">
#         광주 광산구 신창동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132010249" href="/articles/132010249">
# <div class="card-photo ">
# <img alt="나무 선반 책장" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/e36536c11cbf923477d446dfbc9bea7474d455f464513bb64467d3e237ea0010.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">나무 선반 책장</h2>
# <div class="card-price ">
#         5,000원
#       </div>
# <div class="card-region-name">
#         경기도 용인시 처인구 역북동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 14
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132043721" href="/articles/132043721">
# <div class="card-photo ">
# <img alt="옷 서랍장" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/0B0C3887DD4A21CD14912D9BC304884AA606475DF39FC613247610E1CCE7842B.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">옷 서랍장</h2>
# <div class="card-price ">
#         30,000원
#       </div>
# <div class="card-region-name">
#         부산 연제구 연산제3동
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132098786" href="/articles/132098786">
# <div class="card-photo ">
# <img alt="스팸" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/9e64e723b9a77ab9ac942b012236fea761b05b4d079707795edf38983e2be2d4.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스팸</h2>
# <div class="card-price ">
#         10,000원
#       </div>
# <div class="card-region-name">
#         서울 노원구 공릉1동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 10
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132078995" href="/articles/132078995">
# <div class="card-photo ">
# <img alt="컴퓨터" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/bf2026da00e3c7948014d7dab3da51567132476ddf7784eaa97199cee1834fa4.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">컴퓨터</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         경기도 안산시 상록구 본오동
#       </div>
# <div class="card-counts">
# <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132065239" href="/articles/132065239">
# <div class="card-photo ">
# <img alt="자전거 삼천리 아팔란치아 " src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/593232BA11F44F244903C9FDA93D2F8E59BA252CCD12C7453AF50C9BD85DAFA3.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">자전거 삼천리 아팔란치아 </h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         경기도 고양시 일산동구 식사동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132073153" href="/articles/132073153">
# <div class="card-photo ">
# <img alt="실바니안 토끼 세트 " src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/FE24DBC20FFDE8665EF2DDD476DCC42ACB5C10BAA6D73EEFE07719EC364CCF0E.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">실바니안 토끼 세트 </h2>
# <div class="card-price ">
#         5,000원
#       </div>
# <div class="card-region-name">
#         부산 부산진구 양정제2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132005694" href="/articles/132005694">
# <div class="card-photo ">
# <img alt="동원선물세트 64-r호" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/51f36058aae012a891cf39db3ec50c2ed4d3f419b1a9554b5da86e1377c04dc0.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">동원선물세트 64-r호</h2>
# <div class="card-price ">
#         15,000원
#       </div>
# <div class="card-region-name">
#         울산 남구 무거동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132080592" href="/articles/132080592">
# <div class="card-photo ">
# <img alt="DBBC-0329B 접이식 자전거 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/c1caf96a34c7fefa5d9b6ca3cb7a48bc1f11a69987d20805806b494a223c08ab.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">DBBC-0329B 접이식 자전거 팝니다</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         경남 창원시 의창구 북면
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132055206" href="/articles/132055206">
# <div class="card-photo ">
# <img alt="삼성모니터" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/253D4FC9229CF63A137ADF40B53390AA19F41B3652B4D45EC768BDAC58D63EA2.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">삼성모니터</h2>
# <div class="card-price ">
#         80,000원
#       </div>
# <div class="card-region-name">
#         대구 동구 신천동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132046442" href="/articles/132046442">
# <div class="card-photo ">
# <img alt="삼성제습기(15L) 팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/9571A9F1CC245EA93080D98098F294C378AF57A3A3F5D43768ECF76FDBAD27B2.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">삼성제습기(15L) 팔아요</h2>
# <div class="card-price ">
#         100,000원
#       </div>
# <div class="card-region-name">
#         경기도 의왕시 오전동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132112035" href="/articles/132112035">
# <div class="card-photo ">
# <img alt="스마트라32인치 티비" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/173c22fa3a9d23522fdb161513471dd67c662851ceeea0299c52daf067c4bfac.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스마트라32인치 티비</h2>
# <div class="card-price blank-price">
#         -
#       </div>
# <div class="card-region-name">
#         경기도 부천시 중동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132078053" href="/articles/132078053">
# <div class="card-photo ">
# <img alt="루이비통 에바 클러치 (정품)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/2E3A47474D5B4294DA3B38A07EEF98393A99411930A54474C5DEB8EB347B91DE.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">루이비통 에바 클러치 (정품)</h2>
# <div class="card-price ">
#         300,000원
#       </div>
# <div class="card-region-name">
#         서울 송파구 잠실동
#       </div>
# <div class="card-counts">
# <span>
#             관심 12
#           </span>
#         ∙
#         <span>
#             채팅 10
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132031457" href="/articles/132031457">
# <div class="card-photo ">
# <img alt="코렐 4인조" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/6276df7d39bfde182af983e7c427820083611521e48d2f799bd6e1de6b03759b.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">코렐 4인조</h2>
# <div class="card-price ">
#         20,000원
#       </div>
# <div class="card-region-name">
#         부산 연제구 연산동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
# ...
# </div>
# <div class="card-desc">
# <h2 class="card-title">COS 베이비핑크 가디건</h2>
# <div class="card-price ">
#         9,000원
#       </div>
# <div class="card-region-name">
#         서울 종로구 홍파동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132081798" href="/articles/132081798">
# <div class="card-photo ">
# <img alt="제습기 사용 하실분 가져가세요." src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/8cb69e24a73ddf0c5f6a0b5501a9e05fbc163e5c41cb43ec0c8d7481fe9e08c4.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">제습기 사용 하실분 가져가세요.</h2>
# <div class="card-price ">
#         무료나눔
#       </div>
# <div class="card-region-name">
#         광주 북구 각화동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 10
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132065027" href="/articles/132065027">
# <div class="card-photo ">
# <img alt="하프로 루프박스" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/ec7209c1378daad46110145135bb6d6aca27f4cfe8bae4378ccdbb86a0b3e3b2.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">하프로 루프박스</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         서울 양천구 목동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132124480" href="/articles/132124480">
# <div class="card-photo ">
# <img alt="캠핑 타프 팝니다!" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/d393a0a9d819eed2f9880028dfe9b611a1764aaf36e8c3d49c6471e2e95a95d2.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">캠핑 타프 팝니다!</h2>
# <div class="card-price ">
#         20,000원
#       </div>
# <div class="card-region-name">
#         전북 전주시 덕진구 송천동2가
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 9
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="131991688" href="/articles/131991688">
# <div class="card-photo ">
# <img alt="로봇청소기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/690dc775b74c08bbc082ce72d412c0e8c457e68f9dd7c7182988797b6445c3ad.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">로봇청소기</h2>
# <div class="card-price blank-price">
#         -
#       </div>
# <div class="card-region-name">
#         광주 서구 쌍촌동
#       </div>
# <div class="card-counts">
# <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132112950" href="/articles/132112950">
# <div class="card-photo ">
# <img alt="gios 어린이 자전거 Blue 23인치" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/E4D673DB3EB49CA281FB91A45B5EE6FDC039B7B17A2B094ACCAB0C722F0D2492.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">gios 어린이 자전거 Blue 23인치</h2>
# <div class="card-price ">
#         100,000원
#       </div>
# <div class="card-region-name">
#         서울 송파구 잠실2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 9
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132108685" href="/articles/132108685">
# <div class="card-photo ">
# <img alt="컴퓨터의자 저렴하게 내놓습니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/a661e9b06b66c513232cf01d6959497b15d96eb333da126a785cf95acbf73978.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">컴퓨터의자 저렴하게 내놓습니다</h2>
# <div class="card-price ">
#         10,000원
#       </div>
# <div class="card-region-name">
#         경기도 안산시 단원구 신길동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 10
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132125382" href="/articles/132125382">
# <div class="card-photo ">
# <img alt="LP판" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/4e41f790f399398da8e039c2a8915749046d0815c691c7986ea33a168c0f9120.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">LP판</h2>
# <div class="card-price ">
#         20,000원
#       </div>
# <div class="card-region-name">
#         서울 노원구 공릉1동
#       </div>
# <div class="card-counts">
# <span>
#             관심 0
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="131996048" href="/articles/131996048">
# <div class="card-photo ">
# <img alt="갤럭시버즈 라이브 브론즈  새제품" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/851a95c157d8a40319e5d0c6ad768b0217893c75ab6644a8c5d821d72ecd882b.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">갤럭시버즈 라이브 브론즈  새제품</h2>
# <div class="card-price ">
#         130,000원
#       </div>
# <div class="card-region-name">
#         서울 노원구 월계동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132092221" href="/articles/132092221">
# <div class="card-photo ">
# <img alt="선물세트받았는데, 스팸은 안먹어서 올려봅니당" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/D138949997A965A1031F47F4025C36ADB389913C584E3AD86CECE6E7FB6BC9B4.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">선물세트받았는데, 스팸은 안먹어서 올려봅니당</h2>
# <div class="card-price ">
#         15,000원
#       </div>
# <div class="card-region-name">
#         부산 북구 구포제3동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 9
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132077034" href="/articles/132077034">
# <div class="card-photo ">
# <img alt="컴퓨터의자" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/580bca4c472b5808cf71d590e8c0ea93ac5cd268b909a5008c96e4f777aaa81f.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">컴퓨터의자</h2>
# <div class="card-price ">
#         10,000원
#       </div>
# <div class="card-region-name">
#         부산 북구 화명제3동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 10
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132119123" href="/articles/132119123">
# <div class="card-photo ">
# <img alt="자칼텐트" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/4ee4149456800576702a881aaf74288525ba0a13d5fe08245ecbbf0ddd7729df.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">자칼텐트</h2>
# <div class="card-price ">
#         무료나눔
#       </div>
# <div class="card-region-name">
#         경북 안동시 옥동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 9
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132011554" href="/articles/132011554">
# <div class="card-photo ">
# <img alt="한샘 샘키즈 서랍장" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/509107EB0CE86B4598641E963E645A1361C28820BC5CDDA26173F6B3DFB30625.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">한샘 샘키즈 서랍장</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         광주 광산구 신가동
#       </div>
# <div class="card-counts">
# <span>
#             관심 17
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132139951" href="/articles/132139951">
# <div class="card-photo ">
# <img alt="(드림)탄토하우스 원목침대" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/4EB4D267629859671E9A794EF3E7EDF598344B253BA33FD0E13DE2CF89D0CDE7.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">(드림)탄토하우스 원목침대</h2>
# <div class="card-price blank-price">
#         -
#       </div>
# <div class="card-region-name">
#         세종시  다정동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 10
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132066426" href="/articles/132066426">
# <div class="card-photo ">
# <img alt="엔틱 서랍장" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/0f0732427cac112c14d2fc75dbf4fdcbcbc98010f7a99cf7af70bf847c6a50f1.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">엔틱 서랍장</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         광주 서구 동천동
#       </div>
# <div class="card-counts">
# <span>
#             관심 8
#           </span>
#         ∙
#         <span>
#             채팅 9
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132017148" href="/articles/132017148">
# <div class="card-photo ">
# <img alt="알톤 MTB자전거 라피카 4.0D" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/dc3f6f8ab9b2ea40e58c5c433183bd21729a8683b98eb58b03a5b2c531f9c5c4.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">알톤 MTB자전거 라피카 4.0D</h2>
# <div class="card-price ">
#         70,000원
#       </div>
# <div class="card-region-name">
#         대구 남구 대명3동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 9
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="131985556" href="/articles/131985556">
# <div class="card-photo ">
# <img alt="전동킥보드" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/f5edcd1f8ed966491f5230ff021849d71d7ef830fbf8b94293179385b00b46cb.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">전동킥보드</h2>
# <div class="card-price ">
#         250,000원
#       </div>
# <div class="card-region-name">
#         제주 서귀포시 남원읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 14
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="131992732" href="/articles/131992732">
# <div class="card-photo ">
# <img alt="[웅진케어스 제습기]" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/e433fb53e95d6d2c1272a80a15625f300ad27ef5ee9357d56ecab15032e976bb.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">[웅진케어스 제습기]</h2>
# <div class="card-price ">
#         40,000원
#       </div>
# <div class="card-region-name">
#         세종시  도담동
#       </div>
# <div class="card-counts">
# <span>
#             관심 0
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article>
# </section>
# <section id="hot-articles-go-download">
# <h3>
#         더 구경하고 싶나요?
#     </h3>
# <p>당근마켓 앱에서 따뜻한 거래를 직접 경험해보세요!</p>
# <div id="hot-articles-download-buttons">
# <a class="download-button" href="https://itunes.apple.com/kr/app/pangyojangteo/id1018769995?l=ko&amp;ls=1&amp;mt=8" target="_blank">
# <div class="home-apple-store-bar-white"></div>
# <div class="download-text">App Store</div>
# </a> <a class="download-button" href="https://play.google.com/store/apps/details?id=com.towneers.www" target="_blank">
# <div class="home-google-play-bar-white"></div>
# <div class="download-text">Google Play</div>
# </a> </div>
# </section>
# </section>
# <script charset="utf-8" type="text/javascript">
#   function changeRegion(key, value){
#     var url_array
#     if(window.location.pathname === "/hot_articles" && window.location.href.match(/\?/)) {
#       url_array = window.location.href.split('?')[1].split(/(?:r1|&?r2)=/)
#       url_array.unshift("")
#     } else {
#       url_array = window.location.pathname.split('/')
#     }
#     var keys = { r1: 2, r2: 3, r3: 4 }
#     url_array[keys[key]] = value
#     url_array[1] = 'region'
#       if(key == 'r2' && decodeURI(url_array[2]) == "세종특별자치시") {
#         url_array[4] = value
#         url_array[3] = "_"
#       }
#     if(key == 'r1') { url_array.splice(3, 2) }
#     if(key == 'r2' && url_array[3] !== "_") { url_array.splice(4, 1) }
#     window.location.href = window.location.origin + url_array.join('/')
#   }
# </script>
# <footer id="footer">
# <div class="footer-container">
# <div class="footer-top">
# <div class="footer-logo"></div>
# <ul class="footer-list">
# <li class="footer-list-item"><a class="link-highlight" href="/trust">믿을 수 있는 중고거래</a></li>
# <li class="footer-list-item"><a class="link-highlight" href="/wv/faqs">자주 묻는 질문</a></li>
# </ul>
# <ul class="footer-list">
# <li class="footer-list-item"><a href="http://team.daangn.com" target="_blank">회사 소개</a></li>
# <li class="footer-list-item"><a class="link-highlight" href="https://ad.daangn.com/" target="_blank">광고주센터</a></li>
# <li class="footer-list-item">
# <a class="ga-click" data-event-action="hot_articles" data-event-category="town_link_from" data-event-label="footer_town" href="https://town.daangn.com" target="_blank">동네가게</a>
# </li>
# </ul>
# <ul class="footer-list policy">
# <li class="footer-list-item"><a href="https://policy.daangn.com/terms.html" target="_blank">이용약관</a></li>
# <li class="footer-list-item"><a href="https://policy.daangn.com/privacy.html" target="_blank">개인정보취급방침</a></li>
# <li class="footer-list-item"><a href="https://policy.daangn.com/location.html" target="_blank">위치기반서비스 이용약관</a></li>
# </ul>
# </div>
# <div class="footer-bottom">
# <div id="copyright">
# <ul class="copyright-list">
# <li class="copyright-list-item">고객문의 <a href="mailto:cs@daangnservice.com">cs@daangnservice.com</a></li>
# <li class="copyright-list-item">제휴문의 <a href="mailto:contact@daangn.com">contact@daangn.com</a></li>
# </ul>
# <ul class="copyright-list">
# <li class="copyright-list-item">사업자 등록번호 : 375-87-00088</li>
# <li class="copyright-list-item"><address>서울특별시 구로구 디지털로 30길 28 609호</address></li>
# </ul>
# <div class="copyright-text">©Danggeun Market Inc.</div>
# </div>
# <div id="social">
# <ul class="social-list">
# <li class="social-list-item">
# <a class="footer-social-link" href="https://www.facebook.com/daangn" target="_blank">
# <img alt="facebook" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-facebook-0563f4a93852d073b41f13b8bcabb03d47af3bb3a6755cdfedd8a73686c7f18c.svg"/>
# <span class="sr-only">facebook</span>
# </a> </li>
# <li class="social-list-item">
# <a class="footer-social-link" href="https://www.instagram.com/daangnmarket/" target="_blank">
# <img alt="instagram" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-instagram-2f6c88a461597907c114b7ce28eab053fcae791ed26417915fefb6f7c9f95756.svg"/>
# <span class="sr-only">instagram</span>
# </a> </li>
# <li class="social-list-item">
# <a class="footer-social-link" href="https://blog.naver.com/daangn" target="_blank">
# <img alt="blog" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-blog-e1b0d512d1766a6962ec5bbb5b0803d2a6a9c55ad97db5ba9eebb76013caceba.svg"/>
# <span class="sr-only">blog</span>
# </a> </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# </body>
# </html>

# %% [markdown]
# #### 필요한 Library를 가져오고 변수를 지정해주고 soup에 BeautifulSoup 적용
#
# #### Web page에서 F12를 눌렀을 때 표시되는 html 코드가 나온다.

# %% [markdown]
# ## 태그 탐색하기

# %%
print(soup.p)
# Out:
# <p>당근마켓 앱에서 따뜻한 거래를 직접 경험해보세요!</p>

# %%
print(soup.p.string)
# Out:
# 당근마켓 앱에서 따뜻한 거래를 직접 경험해보세요!

# %%
print(soup.h1)
# Out:
# <h1 id="fixed-bar-logo-title">
# <a href="https://www.daangn.com/">
# <span class="sr-only">당근마켓</span>
# <img alt="당근마켓" class="fixed-logo" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg"/>
# </a> </h1>

# %%
for child in soup.h1.children :
    print(child)
# Out:
# <a href="https://www.daangn.com/">
# <span class="sr-only">당근마켓</span>
# <img alt="당근마켓" class="fixed-logo" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg"/>
# </a>

# %% [markdown]
# #### `<a>` 태그의 정보를 출력한다. `<h1>` 태그의 자식 (children) 태그를 가져오는 개념

# %%
for d in soup.div.children :
    print(d)
# Out:
# <h1 id="fixed-bar-logo-title">
# <a href="https://www.daangn.com/">
# <span class="sr-only">당근마켓</span>
# <img alt="당근마켓" class="fixed-logo" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg"/>
# </a> </h1>
#
#
# <section id="fixed-bar-search">
# <div class="search-input-wrap">
# <span class="sr-only">검색</span>
# <input class="fixed-search-input" id="header-search-input" name="header-search-input" placeholder="동네 이름, 물품명 등을 검색해보세요!" type="text"/>
# <button id="header-search-button">
# <img alt="Search" class="fixed-search-icon" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/search-icon-7008edd4f9aaa32188f55e65258f1c1905d7a9d1a3ca2a07ae809b5535380f14.svg"/>
# </button>
# </div>
# </section>
#
#
# <section id="fixed-bar-download">
# <h3 class="hide">다운로드</h3>
# <a class="fixed-download-button" href="https://itunes.apple.com/kr/app/pangyojangteo/id1018769995?l=ko&amp;ls=1&amp;mt=8" id="header-download-button-ios" target="_blank">
# <img alt="App Store" class="fixed-apple-store" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/apple-store-3a664174124650d63cae365bc55586fc5ff27b822b1b97788fc4af77d73d00c8.svg"/>
# <div class="fixed-download-text">App Store</div>
# </a> <a class="fixed-download-button" href="https://play.google.com/store/apps/details?id=com.towneers.www" id="header-download-button-android" target="_blank">
# <img alt="Google Play" class="fixed-google-play" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/google-play-c9ad0fc573cd01e2b982df5de6709a3d8d7cec8d9b58a5c08db7da0b92a32a75.svg"/>
# <div class="fixed-download-text">Google Play</div>
# </a> </section>

# %% [markdown]
# #### find_all() : 원하는 부분을 모두 가져올 때 사용하는 함수

# %%
print( soup.find_all('h2'))
# Out:
# [<h2 class="card-title">위닉스10리터 제습기 급매 1만원</h2>, <h2 class="card-title">캠핑, 잡템 먼저가져가면 장땡</h2>, <h2 class="card-title">아이폰8 화이트 64기가 판매합니다.</h2>, <h2 class="card-title">스팸 판매합니다. </h2>, <h2 class="card-title">이케아 책상 가져가실분</h2>, <h2 class="card-title">복합기</h2>, <h2 class="card-title">캠핑키친테이블(거의새거임)</h2>, <h2 class="card-title">아이폰에어팟 2세대 무선(정품)</h2>, <h2 class="card-title">선물세트 팝니데이</h2>, <h2 class="card-title">전동킥보드</h2>, <h2 class="card-title">타이틀 리스트 골프백</h2>, <h2 class="card-title">제습기</h2>, <h2 class="card-title">스피드랙 선반(새거)</h2>, <h2 class="card-title">캠핑용품-해먹,릴선</h2>, <h2 class="card-title">아이패드 매직키보드 트랙패드 12.9인치</h2>, <h2 class="card-title">제습기</h2>, <h2 class="card-title">아이폰11</h2>, <h2 class="card-title">자전거</h2>, <h2 class="card-title">딥디크 도손향수 </h2>, <h2 class="card-title">몽클레어 야상/바람막이/경량패딩</h2>, <h2 class="card-title">미니책장 드립니다.</h2>, <h2 class="card-title">제습기</h2>, <h2 class="card-title">자전거 판매합니다</h2>, <h2 class="card-title">LG제습기 LD-067DSR</h2>, <h2 class="card-title">전기자전거</h2>, <h2 class="card-title">위닉스 플라즈마웨이브 제습기</h2>, <h2 class="card-title">미니 자전거</h2>, <h2 class="card-title">콤프레샤 ,타카3종,타카심,에어줄,공구함서비스</h2>, <h2 class="card-title">만원에 가져가세요</h2>, <h2 class="card-title">전동킥보드 2대 판매합니다.(성인용)</h2>, <h2 class="card-title">제닉스 아레나 게이밍 의자 판매합니다.</h2>, <h2 class="card-title">어항무료입니다</h2>, <h2 class="card-title">(커피 핸드드립세트) 원두분쇄기, 커피주전자, 커피드리퍼, 커피필터</h2>, <h2 class="card-title">(이전비포함) LG 디오스 김치냉장고 4도어 (405L)</h2>, <h2 class="card-title">체형교정 커블와이더 의자</h2>, <h2 class="card-title">여성용 자전거</h2>, <h2 class="card-title">울산 오토캠핑장 2박 양도</h2>, <h2 class="card-title">아이패드 6세대 128g + 애플펜슬 + 케이스</h2>, <h2 class="card-title">원터치 텐트 및 침낭 판매 합니다.</h2>, <h2 class="card-title">냉장고 미사용 제품</h2>, <h2 class="card-title">각도절단기</h2>, <h2 class="card-title">자전거 판매</h2>, <h2 class="card-title">알톤 자전거 팔아요</h2>, <h2 class="card-title">화분 무료드림합니다</h2>, <h2 class="card-title">숀리 엑스바이크, 실내자전거 판매</h2>, <h2 class="card-title">나무 선반 책장</h2>, <h2 class="card-title">옷 서랍장</h2>, <h2 class="card-title">스팸</h2>, <h2 class="card-title">컴퓨터</h2>, <h2 class="card-title">자전거 삼천리 아팔란치아 </h2>, <h2 class="card-title">실바니안 토끼 세트 </h2>, <h2 class="card-title">동원선물세트 64-r호</h2>, <h2 class="card-title">DBBC-0329B 접이식 자전거 팝니다</h2>, <h2 class="card-title">삼성모니터</h2>, <h2 class="card-title">삼성제습기(15L) 팔아요</h2>, <h2 class="card-title">스마트라32인치 티비</h2>, <h2 class="card-title">루이비통 에바 클러치 (정품)</h2>, <h2 class="card-title">코렐 4인조</h2>, <h2 class="card-title">네스프레소 커피머신 픽시</h2>, <h2 class="card-title">자전거 (성인용, 어린이용, 거치대)</h2>, <h2 class="card-title">캠핑의자테이블묶음판매</h2>, <h2 class="card-title">자전거</h2>, <h2 class="card-title">캠핑테이블</h2>, <h2 class="card-title">숀리 x-bike, 엑스바이크 , 실내자전거</h2>, <h2 class="card-title">나이키 바람막이</h2>, <h2 class="card-title">선물받은 배예요</h2>, <h2 class="card-title">한샘 책상 </h2>, <h2 class="card-title">쌀 라면드림</h2>, <h2 class="card-title">알톤 R Series 로드타입자전거</h2>, <h2 class="card-title">보관만 해둔 자전거 팝니다</h2>, <h2 class="card-title">슈퍼싱글침대 직접가져가시면 무료 침구도 드릴수있어요</h2>, <h2 class="card-title">팝니다</h2>, <h2 class="card-title">카봇, 또봇, 각종로봇들</h2>, <h2 class="card-title">캠핑난로 팝니다( PKH 5000)</h2>, <h2 class="card-title">책상1200사이즈.상태좋음</h2>, <h2 class="card-title">캠핑용 야전침대 판매합니다</h2>, <h2 class="card-title">캠핑용품 일괄처리</h2>, <h2 class="card-title">디월트 각도절단기(마이터쏘) 1년사용 모델명 DW713</h2>, <h2 class="card-title">서랍장</h2>, <h2 class="card-title">COS 베이비핑크 가디건</h2>, <h2 class="card-title">제습기 사용 하실분 가져가세요.</h2>, <h2 class="card-title">하프로 루프박스</h2>, <h2 class="card-title">캠핑 타프 팝니다!</h2>, <h2 class="card-title">로봇청소기</h2>, <h2 class="card-title">gios 어린이 자전거 Blue 23인치</h2>, <h2 class="card-title">컴퓨터의자 저렴하게 내놓습니다</h2>, <h2 class="card-title">LP판</h2>, <h2 class="card-title">갤럭시버즈 라이브 브론즈  새제품</h2>, <h2 class="card-title">선물세트받았는데, 스팸은 안먹어서 올려봅니당</h2>, <h2 class="card-title">컴퓨터의자</h2>, <h2 class="card-title">자칼텐트</h2>, <h2 class="card-title">한샘 샘키즈 서랍장</h2>, <h2 class="card-title">(드림)탄토하우스 원목침대</h2>, <h2 class="card-title">엔틱 서랍장</h2>, <h2 class="card-title">알톤 MTB자전거 라피카 ...

# %% [markdown]
# #### 정규식을 활용할 수 있다 : `<ol> <ul>` 포함하는 값을 리스트로 읽어오고 싶다면?

# %%
import re

# %%
soup.find_all(re.compile('[ou]l'))
# re.compile(pattern) : 패턴 문자열 pattern을 패턴 객체로 컴파일한다
# Out:
# [<ul class="footer-list">
#  <li class="footer-list-item"><a class="link-highlight" href="/trust">믿을 수 있는 중고거래</a></li>
#  <li class="footer-list-item"><a class="link-highlight" href="/wv/faqs">자주 묻는 질문</a></li>
#  </ul>, <ul class="footer-list">
#  <li class="footer-list-item"><a href="http://team.daangn.com" target="_blank">회사 소개</a></li>
#  <li class="footer-list-item"><a class="link-highlight" href="https://ad.daangn.com/" target="_blank">광고주센터</a></li>
#  <li class="footer-list-item">
#  <a class="ga-click" data-event-action="hot_articles" data-event-category="town_link_from" data-event-label="footer_town" href="https://town.daangn.com" target="_blank">동네가게</a>
#  </li>
#  </ul>, <ul class="footer-list policy">
#  <li class="footer-list-item"><a href="https://policy.daangn.com/terms.html" target="_blank">이용약관</a></li>
#  <li class="footer-list-item"><a href="https://policy.daangn.com/privacy.html" target="_blank">개인정보취급방침</a></li>
#  <li class="footer-list-item"><a href="https://policy.daangn.com/location.html" target="_blank">위치기반서비스 이용약관</a></li>
#  </ul>, <ul class="copyright-list">
#  <li class="copyright-list-item">고객문의 <a href="mailto:cs@daangnservice.com">cs@daangnservice.com</a></li>
#  <li class="copyright-list-item">제휴문의 <a href="mailto:contact@daangn.com">contact@daangn.com</a></li>
#  </ul>, <ul class="copyright-list">
#  <li class="copyright-list-item">사업자 등록번호 : 375-87-00088</li>
#  <li class="copyright-list-item"><address>서울특별시 구로구 디지털로 30길 28 609호</address></li>
#  </ul>, <ul class="social-list">
#  <li class="social-list-item">
#  <a class="footer-social-link" href="https://www.facebook.com/daangn" target="_blank">
#  <img alt="facebook" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-facebook-0563f4a93852d073b41f13b8bcabb03d47af3bb3a6755cdfedd8a73686c7f18c.svg"/>
#  <span class="sr-only">facebook</span>
#  </a> </li>
#  <li class="social-list-item">
#  <a class="footer-social-link" href="https://www.instagram.com/daangnmarket/" target="_blank">
#  <img alt="instagram" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-instagram-2f6c88a461597907c114b7ce28eab053fcae791ed26417915fefb6f7c9f95756.svg"/>
#  <span class="sr-only">instagram</span>
#  </a> </li>
#  <li class="social-list-item">
#  <a class="footer-social-link" href="https://blog.naver.com/daangn" target="_blank">
#  <img alt="blog" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-blog-e1b0d512d1766a6962ec5bbb5b0803d2a6a9c55ad97db5ba9eebb76013caceba.svg"/>
#  <span class="sr-only">blog</span>
#  </a> </li>
#  </ul>]

# %%
soup.find_all(re.compile('h[1-9]'))
# <h1> ~ <h9>를 의미
# Out:
# [<h1 id="fixed-bar-logo-title">
#  <a href="https://www.daangn.com/">
#  <span class="sr-only">당근마켓</span>
#  <img alt="당근마켓" class="fixed-logo" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg"/>
#  </a> </h1>,
#  <h3 class="hide">다운로드</h3>,
#  <h1 class="head-title" id="hot-articles-head-title">
#
#
#      중고거래 인기매물
#    </h1>,
#  <h2 class="card-title">위닉스10리터 제습기 급매 1만원</h2>,
#  <h2 class="card-title">캠핑, 잡템 먼저가져가면 장땡</h2>,
#  <h2 class="card-title">아이폰8 화이트 64기가 판매합니다.</h2>,
#  <h2 class="card-title">스팸 판매합니다. </h2>,
#  <h2 class="card-title">이케아 책상 가져가실분</h2>,
#  <h2 class="card-title">복합기</h2>,
#  <h2 class="card-title">캠핑키친테이블(거의새거임)</h2>,
#  <h2 class="card-title">아이폰에어팟 2세대 무선(정품)</h2>,
#  <h2 class="card-title">선물세트 팝니데이</h2>,
#  <h2 class="card-title">전동킥보드</h2>,
#  <h2 class="card-title">타이틀 리스트 골프백</h2>,
#  <h2 class="card-title">제습기</h2>,
#  <h2 class="card-title">스피드랙 선반(새거)</h2>,
#  <h2 class="card-title">캠핑용품-해먹,릴선</h2>,
#  <h2 class="card-title">아이패드 매직키보드 트랙패드 12.9인치</h2>,
#  <h2 class="card-title">제습기</h2>,
#  <h2 class="card-title">아이폰11</h2>,
#  <h2 class="card-title">자전거</h2>,
#  <h2 class="card-title">딥디크 도손향수 </h2>,
#  <h2 class="card-title">몽클레어 야상/바람막이/경량패딩</h2>,
#  <h2 class="card-title">미니책장 드립니다.</h2>,
#  <h2 class="card-title">제습기</h2>,
#  <h2 class="card-title">자전거 판매합니다</h2>,
#  <h2 class="card-title">LG제습기 LD-067DSR</h2>,
#  <h2 class="card-title">전기자전거</h2>,
#  <h2 class="card-title">위닉스 플라즈마웨이브 제습기</h2>,
#  <h2 class="card-title">미니 자전거</h2>,
#  <h2 class="card-title">콤프레샤 ,타카3종,타카심,에어줄,공구함서비스</h2>,
#  <h2 class="card-title">만원에 가져가세요</h2>,
#  <h2 class="card-title">전동킥보드 2대 판매합니다.(성인용)</h2>,
#  <h2 class="card-title">제닉스 아레나 게이밍 의자 판매합니다.</h2>,
#  <h2 class="card-title">어항무료입니다</h2>,
#  <h2 class="card-title">(커피 핸드드립세트) 원두분쇄기, 커피주전자, 커피드리퍼, 커피필터</h2>,
#  <h2 class="card-title">(이전비포함) LG 디오스 김치냉장고 4도어 (405L)</h2>,
#  <h2 class="card-title">체형교정 커블와이더 의자</h2>,
#  <h2 class="card-title">여성용 자전거</h2>,
#  <h2 class="card-title">울산 오토캠핑장 2박 양도</h2>,
#  <h2 class="card-title">아이패드 6세대 128g + 애플펜슬 + 케이스</h2>,
#  <h2 class="card-title">원터치 텐트 및 침낭 판매 합니다.</h2>,
#  <h2 class="card-title">냉장고 미사용 제품</h2>,
#  <h2 class="card-title">각도절단기</h2>,
#  <h2 class="card-title">자전거 판매</h2>,
#  <h2 class="card-title">알톤 자전거 팔아요</h2>,
#  <h2 class="card-title">화분 무료드림합니다</h2>,
#  <h2 class="card-title">숀리 엑스바이크, 실내자전거 판매</h2>,
#  <h2 class="card-title">나무 선반 책장</h2>,
#  <h2 class="card-title">옷 서랍장</h2>,
#  <h2 class="card-title">스팸</h2>,
#  <h2 class="card-title">컴퓨터</h2>,
#  <h2 class="card-title">자전거 삼천리 아팔란치아 </h2>,
#  <h2 class="card-title">실바니안 토끼 세트 </h2>,
#  <h2 class="card-title">동원선물세트 64-r호</h2>,
#  <h2 class="card-title">DBBC-0329B 접이식 자전거 팝니다</h2>,
#  <h2 class="card-title">삼성모니터</h2>,
#  <h2 class="card-title">삼성제습기(15L) 팔아요</h2>,
#  <h2 class="card-title">스마트라32인치 티비</h2>,
#  <h2 class="card-title">루이비통 에바 클러치 (정품)</h2>,
#  <h2 class="card-title">코렐 4인조</h2>,
#  <h2 class="card-title">네스프레소 커피머신 픽시</h2>,
#  <h2 class="card-title">자전거 (성인용, 어린이용, 거치대)</h2>,
#  <h2 class="card-title">캠핑의자테이블묶음판매</h2>,
#  <h2 class="card-title">자전거</h2>,
#  <h2 class="card-title">캠핑테이블</h2>,
#  <h2 class="card-title">숀리 x-bike, 엑스바이크 , 실내자전거</h2>,
#  <h2 class="card-title">나이키 바람막이</h2>,
#  <h2 class="card-title">선물받은 배예요</h2>,
#  <h2 class="card-title">한샘 책상 </h2>,
#  <h2 class="card-title">쌀 라면드림</h2>,
#  <h2 class="card-title">알톤 R Series 로드타입자전거</h2>,
#  <h2 class="card-title">보관만 해둔 자전거 팝니다</h2>,
#  <h2 class="card-title">슈퍼싱글침대 직접가져가시면 무료 침구도 드릴수있어요</h2>,
#  <h2 class="card-title">팝니다</h2>,
#  <h2 class="card-title">카봇, 또봇, 각종로봇들</h2>,
#  <h2 class="card-title">캠핑난로 팝니다( PKH 5000)</h2>,
#  <h2 class="card-title">책상1200사이즈.상태좋음</h2>,
#  <h2 class="card-title">캠핑용 야전침대 판매합니다</h2>,
#  <h2 class="card-title">캠핑용품 일괄처리</h2>,
#  <h2 class="card-title">디월트 각도절단기(마이터쏘) 1년사용 모델명 DW713</h2>,
#  <h2 class="card-title">서랍장</h2>,
#  <h2 class="card-title">COS 베이비핑크 가디건</h2>,
#  <h2 class="card-title">제습기 사용 하실분 가져가세요.</h2>,
#  <h2 class="card-title">하프로 루프박스</h2>,
#  <h2 class="card-title">캠핑 타프 팝니다!</h2>,
#  <h2 class="card-title">로봇청소기</h2>,
#  <h2 class="card-title">gios 어린이 자전거 Blue 23인치</h2>,
#  <h2 class="card-title">컴퓨터의자 저렴하게 내놓습니다</h2>,
#  <h2 class="card-title">LP판</h2>,
#  <h2 class="card-title">갤럭시버즈 라이브 브론즈  새제품</h2>,
#  <h2 class="card-title">선물세트받았는데, 스팸은 안먹어서 올려봅니당</h2>,
#  <h2 class="card-title">컴퓨터의자</h2>,
#  <h2 class="card-title">자칼텐트</h2>,
#  <h2 class="card-title">한샘 샘키즈 서랍장</h2>,
#  <h2 class="card-title">(드림)탄토하우스 원목침대</h2>,
#  <h2 class="card-title">엔틱 서랍장</h2>,
#  <h2 class="card-title">알톤 MTB자전거 라피카 4.0D</h2>,
#  <h2 class="card-title">전동킥보드</h2>,
#  <h2 class="card-title">[웅진케어스 제습기]</h2>,
#  <h3>
#          더 구경하고 싶나요?
#      </h3>]

# %%
soup.find_all(['h1', 'p'])
# 리스트를 사용하면 두가지 이상의 태그를 동시에 가져올 수 있다.
# Out:
# [<h1 id="fixed-bar-logo-title">
#  <a href="https://www.daangn.com/">
#  <span class="sr-only">당근마켓</span>
#  <img alt="당근마켓" class="fixed-logo" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg"/>
#  </a> </h1>, <h1 class="head-title" id="hot-articles-head-title">
#
#
#      중고거래 인기매물
#    </h1>, <p>당근마켓 앱에서 따뜻한 거래를 직접 경험해보세요!</p>]

# %%
soup.find_all(attrs={'class':'card-title'})
# class 속성으로 데이터 가져오기
# Out:
# [<h2 class="card-title">위닉스10리터 제습기 급매 1만원</h2>,
#  <h2 class="card-title">캠핑, 잡템 먼저가져가면 장땡</h2>,
#  <h2 class="card-title">아이폰8 화이트 64기가 판매합니다.</h2>,
#  <h2 class="card-title">스팸 판매합니다. </h2>,
#  <h2 class="card-title">이케아 책상 가져가실분</h2>,
#  <h2 class="card-title">복합기</h2>,
#  <h2 class="card-title">캠핑키친테이블(거의새거임)</h2>,
#  <h2 class="card-title">아이폰에어팟 2세대 무선(정품)</h2>,
#  <h2 class="card-title">선물세트 팝니데이</h2>,
#  <h2 class="card-title">전동킥보드</h2>,
#  <h2 class="card-title">타이틀 리스트 골프백</h2>,
#  <h2 class="card-title">제습기</h2>,
#  <h2 class="card-title">스피드랙 선반(새거)</h2>,
#  <h2 class="card-title">캠핑용품-해먹,릴선</h2>,
#  <h2 class="card-title">아이패드 매직키보드 트랙패드 12.9인치</h2>,
#  <h2 class="card-title">제습기</h2>,
#  <h2 class="card-title">아이폰11</h2>,
#  <h2 class="card-title">자전거</h2>,
#  <h2 class="card-title">딥디크 도손향수 </h2>,
#  <h2 class="card-title">몽클레어 야상/바람막이/경량패딩</h2>,
#  <h2 class="card-title">미니책장 드립니다.</h2>,
#  <h2 class="card-title">제습기</h2>,
#  <h2 class="card-title">자전거 판매합니다</h2>,
#  <h2 class="card-title">LG제습기 LD-067DSR</h2>,
#  <h2 class="card-title">전기자전거</h2>,
#  <h2 class="card-title">위닉스 플라즈마웨이브 제습기</h2>,
#  <h2 class="card-title">미니 자전거</h2>,
#  <h2 class="card-title">콤프레샤 ,타카3종,타카심,에어줄,공구함서비스</h2>,
#  <h2 class="card-title">만원에 가져가세요</h2>,
#  <h2 class="card-title">전동킥보드 2대 판매합니다.(성인용)</h2>,
#  <h2 class="card-title">제닉스 아레나 게이밍 의자 판매합니다.</h2>,
#  <h2 class="card-title">어항무료입니다</h2>,
#  <h2 class="card-title">(커피 핸드드립세트) 원두분쇄기, 커피주전자, 커피드리퍼, 커피필터</h2>,
#  <h2 class="card-title">(이전비포함) LG 디오스 김치냉장고 4도어 (405L)</h2>,
#  <h2 class="card-title">체형교정 커블와이더 의자</h2>,
#  <h2 class="card-title">여성용 자전거</h2>,
#  <h2 class="card-title">울산 오토캠핑장 2박 양도</h2>,
#  <h2 class="card-title">아이패드 6세대 128g + 애플펜슬 + 케이스</h2>,
#  <h2 class="card-title">원터치 텐트 및 침낭 판매 합니다.</h2>,
#  <h2 class="card-title">냉장고 미사용 제품</h2>,
#  <h2 class="card-title">각도절단기</h2>,
#  <h2 class="card-title">자전거 판매</h2>,
#  <h2 class="card-title">알톤 자전거 팔아요</h2>,
#  <h2 class="card-title">화분 무료드림합니다</h2>,
#  <h2 class="card-title">숀리 엑스바이크, 실내자전거 판매</h2>,
#  <h2 class="card-title">나무 선반 책장</h2>,
#  <h2 class="card-title">옷 서랍장</h2>,
#  <h2 class="card-title">스팸</h2>,
#  <h2 class="card-title">컴퓨터</h2>,
#  <h2 class="card-title">자전거 삼천리 아팔란치아 </h2>,
#  <h2 class="card-title">실바니안 토끼 세트 </h2>,
#  <h2 class="card-title">동원선물세트 64-r호</h2>,
#  <h2 class="card-title">DBBC-0329B 접이식 자전거 팝니다</h2>,
#  <h2 class="card-title">삼성모니터</h2>,
#  <h2 class="card-title">삼성제습기(15L) 팔아요</h2>,
#  <h2 class="card-title">스마트라32인치 티비</h2>,
#  <h2 class="card-title">루이비통 에바 클러치 (정품)</h2>,
#  <h2 class="card-title">코렐 4인조</h2>,
#  <h2 class="card-title">네스프레소 커피머신 픽시</h2>,
#  <h2 class="card-title">자전거 (성인용, 어린이용, 거치대)</h2>,
#  <h2 class="card-title">캠핑의자테이블묶음판매</h2>,
#  <h2 class="card-title">자전거</h2>,
#  <h2 class="card-title">캠핑테이블</h2>,
#  <h2 class="card-title">숀리 x-bike, 엑스바이크 , 실내자전거</h2>,
#  <h2 class="card-title">나이키 바람막이</h2>,
#  <h2 class="card-title">선물받은 배예요</h2>,
#  <h2 class="card-title">한샘 책상 </h2>,
#  <h2 class="card-title">쌀 라면드림</h2>,
#  <h2 class="card-title">알톤 R Series 로드타입자전거</h2>,
#  <h2 class="card-title">보관만 해둔 자전거 팝니다</h2>,
#  <h2 class="card-title">슈퍼싱글침대 직접가져가시면 무료 침구도 드릴수있어요</h2>,
#  <h2 class="card-title">팝니다</h2>,
#  <h2 class="card-title">카봇, 또봇, 각종로봇들</h2>,
#  <h2 class="card-title">캠핑난로 팝니다( PKH 5000)</h2>,
#  <h2 class="card-title">책상1200사이즈.상태좋음</h2>,
#  <h2 class="card-title">캠핑용 야전침대 판매합니다</h2>,
#  <h2 class="card-title">캠핑용품 일괄처리</h2>,
#  <h2 class="card-title">디월트 각도절단기(마이터쏘) 1년사용 모델명 DW713</h2>,
#  <h2 class="card-title">서랍장</h2>,
#  <h2 class="card-title">COS 베이비핑크 가디건</h2>,
#  <h2 class="card-title">제습기 사용 하실분 가져가세요.</h2>,
#  <h2 class="card-title">하프로 루프박스</h2>,
#  <h2 class="card-title">캠핑 타프 팝니다!</h2>,
#  <h2 class="card-title">로봇청소기</h2>,
#  <h2 class="card-title">gios 어린이 자전거 Blue 23인치</h2>,
#  <h2 class="card-title">컴퓨터의자 저렴하게 내놓습니다</h2>,
#  <h2 class="card-title">LP판</h2>,
#  <h2 class="card-title">갤럭시버즈 라이브 브론즈  새제품</h2>,
#  <h2 class="card-title">선물세트받았는데, 스팸은 안먹어서 올려봅니당</h2>,
#  <h2 class="card-title">컴퓨터의자</h2>,
#  <h2 class="card-title">자칼텐트</h2>,
#  <h2 class="card-title">한샘 샘키즈 서랍장</h2>,
#  <h2 class="card-title">(드림)탄토하우스 원목침대</h2>,
#  <h2 class="card-title">엔틱 서랍장</h2>,
#  <h2 class="card-title">알톤 MTB자전거 라피카 4.0D</h2>,
#  <h2 class="card-title">전동킥보드</h2>,
#  <h2 class="card-title">[웅진케어스 제습기]</h2>]

# %%
soup.select('.card-title')
# class 속성으로 데이터 가져오기2
# Out:
# [<h2 class="card-title">위닉스10리터 제습기 급매 1만원</h2>,
#  <h2 class="card-title">캠핑, 잡템 먼저가져가면 장땡</h2>,
#  <h2 class="card-title">아이폰8 화이트 64기가 판매합니다.</h2>,
#  <h2 class="card-title">스팸 판매합니다. </h2>,
#  <h2 class="card-title">이케아 책상 가져가실분</h2>,
#  <h2 class="card-title">복합기</h2>,
#  <h2 class="card-title">캠핑키친테이블(거의새거임)</h2>,
#  <h2 class="card-title">아이폰에어팟 2세대 무선(정품)</h2>,
#  <h2 class="card-title">선물세트 팝니데이</h2>,
#  <h2 class="card-title">전동킥보드</h2>,
#  <h2 class="card-title">타이틀 리스트 골프백</h2>,
#  <h2 class="card-title">제습기</h2>,
#  <h2 class="card-title">스피드랙 선반(새거)</h2>,
#  <h2 class="card-title">캠핑용품-해먹,릴선</h2>,
#  <h2 class="card-title">아이패드 매직키보드 트랙패드 12.9인치</h2>,
#  <h2 class="card-title">제습기</h2>,
#  <h2 class="card-title">아이폰11</h2>,
#  <h2 class="card-title">자전거</h2>,
#  <h2 class="card-title">딥디크 도손향수 </h2>,
#  <h2 class="card-title">몽클레어 야상/바람막이/경량패딩</h2>,
#  <h2 class="card-title">미니책장 드립니다.</h2>,
#  <h2 class="card-title">제습기</h2>,
#  <h2 class="card-title">자전거 판매합니다</h2>,
#  <h2 class="card-title">LG제습기 LD-067DSR</h2>,
#  <h2 class="card-title">전기자전거</h2>,
#  <h2 class="card-title">위닉스 플라즈마웨이브 제습기</h2>,
#  <h2 class="card-title">미니 자전거</h2>,
#  <h2 class="card-title">콤프레샤 ,타카3종,타카심,에어줄,공구함서비스</h2>,
#  <h2 class="card-title">만원에 가져가세요</h2>,
#  <h2 class="card-title">전동킥보드 2대 판매합니다.(성인용)</h2>,
#  <h2 class="card-title">제닉스 아레나 게이밍 의자 판매합니다.</h2>,
#  <h2 class="card-title">어항무료입니다</h2>,
#  <h2 class="card-title">(커피 핸드드립세트) 원두분쇄기, 커피주전자, 커피드리퍼, 커피필터</h2>,
#  <h2 class="card-title">(이전비포함) LG 디오스 김치냉장고 4도어 (405L)</h2>,
#  <h2 class="card-title">체형교정 커블와이더 의자</h2>,
#  <h2 class="card-title">여성용 자전거</h2>,
#  <h2 class="card-title">울산 오토캠핑장 2박 양도</h2>,
#  <h2 class="card-title">아이패드 6세대 128g + 애플펜슬 + 케이스</h2>,
#  <h2 class="card-title">원터치 텐트 및 침낭 판매 합니다.</h2>,
#  <h2 class="card-title">냉장고 미사용 제품</h2>,
#  <h2 class="card-title">각도절단기</h2>,
#  <h2 class="card-title">자전거 판매</h2>,
#  <h2 class="card-title">알톤 자전거 팔아요</h2>,
#  <h2 class="card-title">화분 무료드림합니다</h2>,
#  <h2 class="card-title">숀리 엑스바이크, 실내자전거 판매</h2>,
#  <h2 class="card-title">나무 선반 책장</h2>,
#  <h2 class="card-title">옷 서랍장</h2>,
#  <h2 class="card-title">스팸</h2>,
#  <h2 class="card-title">컴퓨터</h2>,
#  <h2 class="card-title">자전거 삼천리 아팔란치아 </h2>,
#  <h2 class="card-title">실바니안 토끼 세트 </h2>,
#  <h2 class="card-title">동원선물세트 64-r호</h2>,
#  <h2 class="card-title">DBBC-0329B 접이식 자전거 팝니다</h2>,
#  <h2 class="card-title">삼성모니터</h2>,
#  <h2 class="card-title">삼성제습기(15L) 팔아요</h2>,
#  <h2 class="card-title">스마트라32인치 티비</h2>,
#  <h2 class="card-title">루이비통 에바 클러치 (정품)</h2>,
#  <h2 class="card-title">코렐 4인조</h2>,
#  <h2 class="card-title">네스프레소 커피머신 픽시</h2>,
#  <h2 class="card-title">자전거 (성인용, 어린이용, 거치대)</h2>,
#  <h2 class="card-title">캠핑의자테이블묶음판매</h2>,
#  <h2 class="card-title">자전거</h2>,
#  <h2 class="card-title">캠핑테이블</h2>,
#  <h2 class="card-title">숀리 x-bike, 엑스바이크 , 실내자전거</h2>,
#  <h2 class="card-title">나이키 바람막이</h2>,
#  <h2 class="card-title">선물받은 배예요</h2>,
#  <h2 class="card-title">한샘 책상 </h2>,
#  <h2 class="card-title">쌀 라면드림</h2>,
#  <h2 class="card-title">알톤 R Series 로드타입자전거</h2>,
#  <h2 class="card-title">보관만 해둔 자전거 팝니다</h2>,
#  <h2 class="card-title">슈퍼싱글침대 직접가져가시면 무료 침구도 드릴수있어요</h2>,
#  <h2 class="card-title">팝니다</h2>,
#  <h2 class="card-title">카봇, 또봇, 각종로봇들</h2>,
#  <h2 class="card-title">캠핑난로 팝니다( PKH 5000)</h2>,
#  <h2 class="card-title">책상1200사이즈.상태좋음</h2>,
#  <h2 class="card-title">캠핑용 야전침대 판매합니다</h2>,
#  <h2 class="card-title">캠핑용품 일괄처리</h2>,
#  <h2 class="card-title">디월트 각도절단기(마이터쏘) 1년사용 모델명 DW713</h2>,
#  <h2 class="card-title">서랍장</h2>,
#  <h2 class="card-title">COS 베이비핑크 가디건</h2>,
#  <h2 class="card-title">제습기 사용 하실분 가져가세요.</h2>,
#  <h2 class="card-title">하프로 루프박스</h2>,
#  <h2 class="card-title">캠핑 타프 팝니다!</h2>,
#  <h2 class="card-title">로봇청소기</h2>,
#  <h2 class="card-title">gios 어린이 자전거 Blue 23인치</h2>,
#  <h2 class="card-title">컴퓨터의자 저렴하게 내놓습니다</h2>,
#  <h2 class="card-title">LP판</h2>,
#  <h2 class="card-title">갤럭시버즈 라이브 브론즈  새제품</h2>,
#  <h2 class="card-title">선물세트받았는데, 스팸은 안먹어서 올려봅니당</h2>,
#  <h2 class="card-title">컴퓨터의자</h2>,
#  <h2 class="card-title">자칼텐트</h2>,
#  <h2 class="card-title">한샘 샘키즈 서랍장</h2>,
#  <h2 class="card-title">(드림)탄토하우스 원목침대</h2>,
#  <h2 class="card-title">엔틱 서랍장</h2>,
#  <h2 class="card-title">알톤 MTB자전거 라피카 4.0D</h2>,
#  <h2 class="card-title">전동킥보드</h2>,
#  <h2 class="card-title">[웅진케어스 제습기]</h2>]

# %%
soup.select('#hot-articles-navigation')
# id 속성으로 데이터 가져오기
# Out:
# [<nav id="hot-articles-navigation">
#  <select class="hot-articles-nav-select" id="region1" name="region1" onchange="changeRegion('r1', this.value)"><option value="">지역을 선택하세요</option><option value="서울특별시">서울특별시</option>
#  <option value="부산광역시">부산광역시</option>
#  <option value="대구광역시">대구광역시</option>
#  <option value="인천광역시">인천광역시</option>
#  <option value="광주광역시">광주광역시</option>
#  <option value="대전광역시">대전광역시</option>
#  <option value="울산광역시">울산광역시</option>
#  <option value="세종특별자치시">세종특별자치시</option>
#  <option value="경기도">경기도</option>
#  <option value="강원도">강원도</option>
#  <option value="충청북도">충청북도</option>
#  <option value="충청남도">충청남도</option>
#  <option value="전라북도">전라북도</option>
#  <option value="전라남도">전라남도</option>
#  <option value="경상북도">경상북도</option>
#  <option value="경상남도">경상남도</option>
#  <option value="제주특별자치도">제주특별자치도</option></select>
#  <select class="hot-articles-nav-select" disabled="disabled" id="region2" name="region2" onchange="changeRegion('r2', this.value)"><option value="">동네를 선택하세요</option><option value="서울특별시">서울특별시</option>
#  <option value="부산광역시">부산광역시</option>
#  <option value="대구광역시">대구광역시</option>
#  <option value="인천광역시">인천광역시</option>
#  <option value="광주광역시">광주광역시</option>
#  <option value="대전광역시">대전광역시</option>
#  <option value="울산광역시">울산광역시</option>
#  <option value="세종특별자치시">세종특별자치시</option>
#  <option value="경기도">경기도</option>
#  <option value="강원도">강원도</option>
#  <option value="충청북도">충청북도</option>
#  <option value="충청남도">충청남도</option>
#  <option value="전라북도">전라북도</option>
#  <option value="전라남도">전라남도</option>
#  <option value="경상북도">경상북도</option>
#  <option value="경상남도">경상남도</option>
#  <option value="제주특별자치도">제주특별자치도</option></select>
#  </nav>]

# %%
for idx in range(0,10) :
    print(soup.select('.card-title')[idx].get_text())
 # 태그 안의 텍스트 가져오기
# Out:
# 위닉스10리터 제습기 급매 1만원
# 캠핑, 잡템 먼저가져가면 장땡
# 아이폰8 화이트 64기가 판매합니다.
# 스팸 판매합니다.
# 이케아 책상 가져가실분
# 복합기
# 캠핑키친테이블(거의새거임)
# 아이폰에어팟 2세대 무선(정품)
# 선물세트 팝니데이
# 전동킥보드

# %% [markdown]
# #### get_text : 텍스트만 출력하는 함수

# %%
# 한글 폰트 문제 해결
import platform

from matplotlib import font_manager, rc
# plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
html = urlopen('https://www.daangn.com/hot_articles')

# urlopen 으로 url을 불러왔을 경우 html.read() 사용
soup = BeautifulSoup(html.read() , 'html.parser')

print(soup.h1)

# %%
from urllib.request import urlopen
from urllib.error   import HTTPError
from urllib.error   import URLError

# %%
try:
    html = urlopen('https://www.daangn.com/hot_articles')
except HTTPError as he :
    print('http error')
except URLError as ue :
    print('url error')
else :
    soup = BeautifulSoup(html.read() , 'html.parser')
    print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
# <link href="https://www.daangn.com/hot_articles" rel="canonical"/>
# <title>당근마켓 중고거래 | 당신 근처의 당근마켓</title>
# <meta content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." name="description"/>
# <meta content="https://www.daangn.com/hot_articles" property="og:url"/>
# <meta content="당근마켓 중고거래 | 당신 근처의 당근마켓" property="og:title"/>
# <meta content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." property="og:description"/>
# <meta content="당근마켓" property="og:site_name"/>
# <meta content="https://www.daangn.com/images/meta/home/flea_market.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="ko_KR" property="og:locale"/>
# <meta content="1463621440622064" property="fb:app_id"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@danggeunmarket" name="twitter:site"/>
# <meta content="당근마켓 중고거래 | 당신 근처의 당근마켓" name="twitter:title"/>
# <meta content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." name="twitter:description"/>
# <meta content="https://www.daangn.com/images/meta/home/flea_market.png" name="twitter:image"/>
# <meta content="당근마켓" name="author"/>
# <meta content="8273a462d4256dc90c43fbfa8ecbe29675ede28c" name="naver-site-verification"/>
# <link href="/images/icons/shortcut_icon.png" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://d1unjqcospf8gs.cloudfront.net/favicon.ico" rel="shortcut icon" type="image/x-icon">
# <link href="https://d1unjqcospf8gs.cloudfront.net/assets/home/articles/hot-5a66164356b6257c2849e833649bd7482f5f581e017feb9f28e477ca285f9cfa.css" media="all" rel="stylesheet"/>
# <script src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base-d5f8bd2e2e6729d4f86324f85bbdb9a5c6bafeff1957b761a1187ae9c7d773b8.js"></script>
# <link href="https://fonts.googleapis.com/css2?family=Noto+Sans+KR:wght@400;700" rel="stylesheet"/>
# <link href="/images/icons/daangn_logo_192.png" rel="apple-touch-icon" sizes="192x192"/>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
#   <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#   <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#   <![endif]-->
# <meta content="authenticity_token" name="csrf-param">
# <meta content="GhL8eNIy+PmHZWHtgpFskqDXlrmQO4wJMTaiGYF5xnZ5vx+54aUFCyZxxHCMLgx8mqy16cGhJUIkiHxKUuFbkA==" name="csrf-token">
# <script>
#     window.fbAsyncInit = function() {
#       FB.init({
#         appId      : '1463621440622064',
#         xfbml      : true,
#         version    : 'v2.4'
#       });
#     };
#
#     (function(d, s, id){
#       var js, fjs = d.getElementsByTagName(s)[0];
#       if (d.getElementById(id)) {return;}
#       js = d.createElement(s); js.id = id;
#       js.src = "//connect.facebook.net/en_US/sdk.js";
#       fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
#   </script>
# <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#               (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#             m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-64551386-2', 'auto');
#      ga('set', 'dimension2', 'true');  ga('send', 'pageview'); </script>
# <!-- Facebook Pixel Code -->
# <script>
#       !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#               n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#         n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#         t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#               document,'script','//connect.facebook.net/en_US/fbevents.js');
#
#       fbq('init', '992961397411651');
#       fbq('track', "PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=992961397411651&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-PJSK4QL');</script>
# <!-- End Google Tag Manager -->
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "name": "당근마켓",
#   "url": "https://www.daangn.com",
#   "sameAs": [
#     "https://www.facebook.com/daangn",
#     "https://blog.naver.com/daangn",
#     "https://www.youtube.com/channel/UC8tsBsQBuF7QybxgLmStihA",
#     "https://twitter.com/danggeunmarket",
#     "https://www.instagram.com/daangnmarket",
#     "https://itunes.apple.com/kr/app/id1018769995",
#     "https://play.google.com/store/apps/details?id=com.towneers.www"
#   ]
# }
# </script>
# </meta></meta></link></head>
# <body class="hoian-kr">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJSK4QL" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header id="fixed-bar">
# <div id="fixed-bar-wrap">
# <h1 id="fixed-bar-logo-title">
# <a href="https://www.daangn.com/">
# <span class="sr-only">당근마켓</span>
# <img alt="당근마켓" class="fixed-logo" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg"/>
# </a> </h1>
# <section id="fixed-bar-search">
# <div class="search-input-wrap">
# <span class="sr-only">검색</span>
# <input class="fixed-search-input" id="header-search-input" name="header-search-input" placeholder="동네 이름, 물품명 등을 검색해보세요!" type="text"/>
# <button id="header-search-button">
# <img alt="Search" class="fixed-search-icon" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/search-icon-7008edd4f9aaa32188f55e65258f1c1905d7a9d1a3ca2a07ae809b5535380f14.svg"/>
# </button>
# </div>
# </section>
# <section id="fixed-bar-download">
# <h3 class="hide">다운로드</h3>
# <a class="fixed-download-button" href="https://itunes.apple.com/kr/app/pangyojangteo/id1018769995?l=ko&amp;ls=1&amp;mt=8" id="header-download-button-ios" target="_blank">
# <img alt="App Store" class="fixed-apple-store" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/apple-store-3a664174124650d63cae365bc55586fc5ff27b822b1b97788fc4af77d73d00c8.svg"/>
# <div class="fixed-download-text">App Store</div>
# </a> <a class="fixed-download-button" href="https://play.google.com/store/apps/details?id=com.towneers.www" id="header-download-button-android" target="_blank">
# <img alt="Google Play" class="fixed-google-play" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/google-play-c9ad0fc573cd01e2b982df5de6709a3d8d7cec8d9b58a5c08db7da0b92a32a75.svg"/>
# <div class="fixed-download-text">Google Play</div>
# </a> </section>
# </div>
# </header>
# <section id="content">
# <h1 class="head-title" id="hot-articles-head-title">
#
#
#     중고거래 인기매물
#   </h1>
# <nav id="hot-articles-navigation">
# <select class="hot-articles-nav-select" id="region1" name="region1" onchange="changeRegion('r1', this.value)"><option value="">지역을 선택하세요</option><option value="서울특별시">서울특별시</option>
# <option value="부산광역시">부산광역시</option>
# <option value="대구광역시">대구광역시</option>
# <option value="인천광역시">인천광역시</option>
# <option value="광주광역시">광주광역시</option>
# <option value="대전광역시">대전광역시</option>
# <option value="울산광역시">울산광역시</option>
# <option value="세종특별자치시">세종특별자치시</option>
# <option value="경기도">경기도</option>
# <option value="강원도">강원도</option>
# <option value="충청북도">충청북도</option>
# <option value="충청남도">충청남도</option>
# <option value="전라북도">전라북도</option>
# <option value="전라남도">전라남도</option>
# <option value="경상북도">경상북도</option>
# <option value="경상남도">경상남도</option>
# <option value="제주특별자치도">제주특별자치도</option></select>
# <select class="hot-articles-nav-select" disabled="disabled" id="region2" name="region2" onchange="changeRegion('r2', this.value)"><option value="">동네를 선택하세요</option><option value="서울특별시">서울특별시</option>
# <option value="부산광역시">부산광역시</option>
# <option value="대구광역시">대구광역시</option>
# <option value="인천광역시">인천광역시</option>
# <option value="광주광역시">광주광역시</option>
# <option value="대전광역시">대전광역시</option>
# <option value="울산광역시">울산광역시</option>
# <option value="세종특별자치시">세종특별자치시</option>
# <option value="경기도">경기도</option>
# <option value="강원도">강원도</option>
# <option value="충청북도">충청북도</option>
# <option value="충청남도">충청남도</option>
# <option value="전라북도">전라북도</option>
# <option value="전라남도">전라남도</option>
# <option value="경상북도">경상북도</option>
# <option value="경상남도">경상남도</option>
# <option value="제주특별자치도">제주특별자치도</option></select>
# </nav>
# <section class="cards-wrap">
# <article class="card-top ">
# <a class="card-link " data-event-label="132195674" href="/articles/132195674">
# <div class="card-photo ">
# <img alt="철제선반(코너틈새수납)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/e7fef132121a7f421547238a3c8cf54e6a37a20364917d4ca11436cddb7136a9.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">철제선반(코너틈새수납)</h2>
# <div class="card-price ">
#         3,000원
#       </div>
# <div class="card-region-name">
#         서울 노원구 중계2.3동
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 24
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132162678" href="/articles/132162678">
# <div class="card-photo ">
# <img alt="스팸" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/f76fcb7b0ed7b3be5f4225299bdb7a05b646b280758d721360917c25ca6b5a96.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스팸</h2>
# <div class="card-price ">
#         5,000원
#       </div>
# <div class="card-region-name">
#         서울 강서구 내발산동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 25
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132137750" href="/articles/132137750">
# <div class="card-photo ">
# <img alt="캠핑, 잡템 먼저가져가면 장땡" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/07347eb8dfecbb8c78f76b7ff5fb9f442ab78075f693593a900d129dd054505a.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">캠핑, 잡템 먼저가져가면 장땡</h2>
# <div class="card-price ">
#         무료나눔
#       </div>
# <div class="card-region-name">
#         전북 전주시 완산구 효자4동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 23
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132075404" href="/articles/132075404">
# <div class="card-photo ">
# <img alt="아이폰8 화이트 64기가 판매합니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/DD19A0BE7D83B46A7763BF2691BF634E7AFC5B406CC379AEBBD628D4EEF3D88F.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이폰8 화이트 64기가 판매합니다.</h2>
# <div class="card-price ">
#         100,000원
#       </div>
# <div class="card-region-name">
#         경북 구미시 인동동
#       </div>
# <div class="card-counts">
# <span>
#             관심 14
#           </span>
#         ∙
#         <span>
#             채팅 32
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132113235" href="/articles/132113235">
# <div class="card-photo ">
# <img alt="중고 자전거(5~10만원 선택 가능^^)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/751633fcaa378c596cf00e3c7e77979cc4ccadbe5224bc2a34f346383c564047.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">중고 자전거(5~10만원 선택 가능^^)</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         경기도 성남시 분당구 서현1동
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 24
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132070105" href="/articles/132070105">
# <div class="card-photo ">
# <img alt="위닉스10리터 제습기 급매 1만원" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/0762b109344a9b40fa99e91d02f20f6fcb3c5e3a69b3e7fd9dba4a44660b7fee.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">위닉스10리터 제습기 급매 1만원</h2>
# <div class="card-price ">
#         10,000원
#       </div>
# <div class="card-region-name">
#         대전 중구 문화1동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 21
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132147127" href="/articles/132147127">
# <div class="card-photo ">
# <img alt="캠핑용 릴선 27m" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/7ebd3a82e549b5c3886aee2696ea6fe624202a663621a0354b9fde0e10d23b66.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">캠핑용 릴선 27m</h2>
# <div class="card-price ">
#         5,000원
#       </div>
# <div class="card-region-name">
#         경기도 수원시 영통구 영통동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132166976" href="/articles/132166976">
# <div class="card-photo ">
# <img alt="스팸+카놀라유 선물세트" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/417f3ed2efb418d4423a179843d4ee162f4d37ef1ac2c1a36cb45824e5e3ab60.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스팸+카놀라유 선물세트</h2>
# <div class="card-price ">
#         10,000원
#       </div>
# <div class="card-region-name">
#         경기도 고양시 덕양구 행신3동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132012531" href="/articles/132012531">
# <div class="card-photo ">
# <img alt="이케아 책상 가져가실분" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/41C36378AA7950B639C3724D082C7CBA7F908E55B2B62F93473ABF3A2A0152A0.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">이케아 책상 가져가실분</h2>
# <div class="card-price ">
#         1원
#       </div>
# <div class="card-region-name">
#         대구 중구 남산4동
#       </div>
# <div class="card-counts">
# <span>
#             관심 13
#           </span>
#         ∙
#         <span>
#             채팅 26
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132153896" href="/articles/132153896">
# <div class="card-photo ">
# <img alt="냉장고 싸게 드립니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/03DBF79BF13F92942102229F143B9B31643F62F99A460218EAF7F03B4E1B383D.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">냉장고 싸게 드립니다</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         서울 서초구 서초동
#       </div>
# <div class="card-counts">
# <span>
#             관심 8
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132110036" href="/articles/132110036">
# <div class="card-photo ">
# <img alt="복합기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/65a2710ea1d6813186e8bcdfa79377b7799e4e086fdfdc67253c3cba7be6a191.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">복합기</h2>
# <div class="card-price ">
#         무료나눔
#       </div>
# <div class="card-region-name">
#         경기도 안산시 단원구 중앙동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132139025" href="/articles/132139025">
# <div class="card-photo ">
# <img alt="딥디크 도손향수 " src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/1207089AD5F56D05FC0ED851193CF46B1F4FD5E7B203EBBD810146B33740E4BD.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">딥디크 도손향수 </h2>
# <div class="card-price ">
#         12,000원
#       </div>
# <div class="card-region-name">
#         서울 관악구 은천동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132072045" href="/articles/132072045">
# <div class="card-photo ">
# <img alt="스팸 판매합니다. " src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/FD8082154C5793C515A4EE7A042C4EAD6BDFE3183F1D60DD38E834946A9CAE2A.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스팸 판매합니다. </h2>
# <div class="card-price ">
#         10,000원
#       </div>
# <div class="card-region-name">
#         경기도 고양시 일산서구 주엽1동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132188234" href="/articles/132188234">
# <div class="card-photo ">
# <img alt="보드게임 루미큐브" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/6D0B00506EC6FD33987258CF2263B0753F139A8BC53294AE16E871DCFC2F6A2B.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">보드게임 루미큐브</h2>
# <div class="card-price ">
#         5,000원
#       </div>
# <div class="card-region-name">
#         서울 마포구 연남동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132079778" href="/articles/132079778">
# <div class="card-photo ">
# <img alt="선물세트 팝니데이" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/1822DFB926594A3AAE59EF763C620335CE4A416E66D17F91A326A5BEC98DAC18.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">선물세트 팝니데이</h2>
# <div class="card-price ">
#         18,000원
#       </div>
# <div class="card-region-name">
#         부산 부산진구 범천동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132003228" href="/articles/132003228">
# <div class="card-photo ">
# <img alt="캠핑키친테이블(거의새거임)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/BC4239739883AEB7043E1BDD469C8B6CCEC585E8D2052C3A24E366A21D19E7A1.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">캠핑키친테이블(거의새거임)</h2>
# <div class="card-price ">
#         25,000원
#       </div>
# <div class="card-region-name">
#         부산 수영구 광안동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="131860379" href="/articles/131860379">
# <div class="card-photo ">
# <img alt="아이폰11" src="https://dnvefa72aowie.cloudfront.net/origin/article/202009/4e7f7f1a23030894c727b8d0e7018fef15b27a94d25dbac8760f9aa33a5eac37.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이폰11</h2>
# <div class="card-price ">
#         100,000원
#       </div>
# <div class="card-region-name">
#         부산 부산진구 전포동
#       </div>
# <div class="card-counts">
# <span>
#             관심 17
#           </span>
#         ∙
#         <span>
#             채팅 59
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="131940414" href="/articles/131940414">
# <div class="card-photo ">
# <img alt="아이폰에어팟 2세대 무선(정품)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202009/a891177f8214b103c8b59c46726e9fb5e07dd309db96af10c7472905008f1734.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이폰에어팟 2세대 무선(정품)</h2>
# <div class="card-price ">
#         20,000원
#       </div>
# <div class="card-region-name">
#         부산 부산진구 전포동
#       </div>
# <div class="card-counts">
# <span>
#             관심 17
#           </span>
#         ∙
#         <span>
#             채팅 41
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132198135" href="/articles/132198135">
# <div class="card-photo ">
# <img alt="아이폰7판매합니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/4e3d0947a62ee15d11735b8fe0c98ca4ee27ec8d10e98e72cf392e173e48934e.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이폰7판매합니다</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         대구 수성구 범어4동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132126018" href="/articles/132126018">
# <div class="card-photo ">
# <img alt="제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/50b0fce4ea3676674dbc0a4496d346397add86d5ecd1afe7143474f3967a594d.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">제습기</h2>
# <div class="card-price ">
#         무료나눔
#       </div>
# <div class="card-region-name">
#         서울 마포구 성산동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132055359" href="/articles/132055359">
# <div class="card-photo ">
# <img alt="타이틀 리스트 골프백" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/3ed708af47ae141446712c5b9d49aabccd34e535fa061faac1352e52e32a086b.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">타이틀 리스트 골프백</h2>
# <div class="card-price ">
#         30,000원
#       </div>
# <div class="card-region-name">
#         경기도 화성시 동탄5동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132020602" href="/articles/132020602">
# <div class="card-photo ">
# <img alt="스피드랙 선반(새거)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/0f1cfe552292ca44dd0c9bb0ce95f7cb64d5d5fa97721b62d3bad63ab04d20d4.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스피드랙 선반(새거)</h2>
# <div class="card-price ">
#         15,000원
#       </div>
# <div class="card-region-name">
#         부산 강서구 명지동
#       </div>
# <div class="card-counts">
# <span>
#             관심 8
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132026639" href="/articles/132026639">
# <div class="card-photo ">
# <img alt="캠핑용품-해먹,릴선" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/DCC073C63206BCF1F92557D44722DAE7A8C7BA85FA6522D9846B8CBE22768C06.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">캠핑용품-해먹,릴선</h2>
# <div class="card-price ">
#         5,000원
#       </div>
# <div class="card-region-name">
#         경기도 안산시 단원구 고잔동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132203082" href="/articles/132203082">
# <div class="card-photo ">
# <img alt="스팸" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/072da4efafc2243aeee70b9b536dc9369dc988c9a9a9cdcad74e48264367400b.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스팸</h2>
# <div class="card-price ">
#         20,000원
#       </div>
# <div class="card-region-name">
#         경기도 김포시 장기동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 14
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132088403" href="/articles/132088403">
# <div class="card-photo ">
# <img alt="자전거" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/8c802021bf2c9de5836bef8537e5132d2a439ab3dcb6c15e3b79098e05c9fd44.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">자전거</h2>
# <div class="card-price ">
#         무료나눔
#       </div>
# <div class="card-region-name">
#         경기도 수원시 영통구 망포동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132164966" href="/articles/132164966">
# <div class="card-photo ">
# <img alt="수납장" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/1de77966816d625a0215667fc99f3a2a1bab977eed914696505486a023528d78.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">수납장</h2>
# <div class="card-price ">
#         10,000원
#       </div>
# <div class="card-region-name">
#         전북 군산시 수송동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132214243" href="/articles/132214243">
# <div class="card-photo ">
# <img alt="압력밥솥" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/41A3C31932EFA4B82147BE97BBA52CEF8FDC13D86BD47F3E80CA6F59AE075492.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">압력밥솥</h2>
# <div class="card-price ">
#         3,000원
#       </div>
# <div class="card-region-name">
#         대구 달서구 용산1동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132109549" href="/articles/132109549">
# <div class="card-photo ">
# <img alt="아이패드 매직키보드 트랙패드 12.9인치" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/17369596B5BF0962D5D5D47370CD02BEF46DF4210AE4C87BD7CE7964D3FADB0A.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이패드 매직키보드 트랙패드 12.9인치</h2>
# <div class="card-price ">
#         100,000원
#       </div>
# <div class="card-region-name">
#         서울 마포구 용강동
#       </div>
# <div class="card-counts">
# <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132166729" href="/articles/132166729">
# <div class="card-photo ">
# <img alt="루이비통 네버풀 PM 다미에라인" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/08D12037AFFAD78757EB5D45088F8C75710DF22C94FF7B35BBD23AFCCF0BE8E9.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">루이비통 네버풀 PM 다미에라인</h2>
# <div class="card-price ">
#         200,000원
#       </div>
# <div class="card-region-name">
#         경기도 성남시 분당구 서현2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132023626" href="/articles/132023626">
# <div class="card-photo ">
# <img alt="제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/59991380a1a1d06d32b0ed6bd6bab0368cbee11e28c4535fdfc61dd969b8c694.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">제습기</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         인천 미추홀구 주안5동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132195914" href="/articles/132195914">
# <div class="card-photo ">
# <img alt="이케아 철제 선반" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/88BE2B4452C12895F428A37A17DBC519FFDD90006C9079DA9E500A16837AEF8B.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">이케아 철제 선반</h2>
# <div class="card-price ">
#         7,000원
#       </div>
# <div class="card-region-name">
#         서울 강서구 화곡제4동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132178853" href="/articles/132178853">
# <div class="card-photo ">
# <img alt="전자렌지무료" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/6F73A62B0C62449FDB8DDE6D828CA794AAF962A76C019E77D697EDF344C8DC26.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">전자렌지무료</h2>
# <div class="card-price blank-price">
#         -
#       </div>
# <div class="card-region-name">
#         부산 남구 문현제2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 0
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132208270" href="/articles/132208270">
# <div class="card-photo ">
# <img alt="냉장고" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/17122d062ba149cc538a710200ffae3013c17afb8e7d6317e60ed7b018f7cfb8.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">냉장고</h2>
# <div class="card-price ">
#         80,000원
#       </div>
# <div class="card-region-name">
#         부산 수영구 수영동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132186832" href="/articles/132186832">
# <div class="card-photo ">
# <img alt="스토케 트립트랩" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/1F24BDCCD9D5B82B25367E0B5FA2C9061F05C9DFF0FE8166A166E7DCC28EE5CA.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스토케 트립트랩</h2>
# <div class="card-price ">
#         20,000원
#       </div>
# <div class="card-region-name">
#         서울 영등포구 여의동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132047146" href="/articles/132047146">
# <div class="card-photo ">
# <img alt="자전거 판매합니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/403f4cbb0aa42445337cacae79cc406b86eec5ea9fde51697a25e9d1c854318f.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">자전거 판매합니다</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         서울 노원구 월계3동
#       </div>
# <div class="card-counts">
# <span>
#             관심 8
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132044830" href="/articles/132044830">
# <div class="card-photo ">
# <img alt="원터치 텐트 및 침낭 판매 합니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/9d43f9479ab0e05135404755049ef4112e21928410d90717d601ead8604755bf.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">원터치 텐트 및 침낭 판매 합니다.</h2>
# <div class="card-price ">
#         20,000원
#       </div>
# <div class="card-region-name">
#         경남 창원시 성산구 반림동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132005237" href="/articles/132005237">
# <div class="card-photo ">
# <img alt="몽클레어 야상/바람막이/경량패딩" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/470a563c748fabe64c48445d3f107b5ef8270757982680e4b440014406c5849c.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">몽클레어 야상/바람막이/경량패딩</h2>
# <div class="card-price ">
#         100,000원
#       </div>
# <div class="card-region-name">
#         서울 서초구 반포2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 12
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132049730" href="/articles/132049730">
# <div class="card-photo ">
# <img alt="LG제습기 LD-067DSR" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/faead531ace040322c68247d2764204bacb287dc36b30437f71604989fe64067.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">LG제습기 LD-067DSR</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         인천 계양구 계산동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132107086" href="/articles/132107086">
# <div class="card-photo ">
# <img alt="전기자전거" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/0b105f227adea147daaffbbe9e7bda1b1cc3629272648469a42776977d620036.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">전기자전거</h2>
# <div class="card-price ">
#         80,000원
#       </div>
# <div class="card-region-name">
#         서울 서초구 서초4동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132049016" href="/articles/132049016">
# <div class="card-photo ">
# <img alt="제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/64f34b50237471341d923d9e8825327806756cf535aa6a8f6b6f1e7c970f00aa.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">제습기</h2>
# <div class="card-price ">
#         10,000원
#       </div>
# <div class="card-region-name">
#         경기도 광주시 오포읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132054711" href="/articles/132054711">
# <div class="card-photo ">
# <img alt="미니책장 드립니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/facc94efcbf4e7c2f28c0242fed2fdc0bf8272c3a49a672794e5058b5a64752d.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">미니책장 드립니다.</h2>
# <div class="card-price ">
#         무료나눔
#       </div>
# <div class="card-region-name">
#         경기도 평택시 원평동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132122798" href="/articles/132122798">
# <div class="card-photo ">
# <img alt="슈퍼싱글침대 직접가져가시면 무료 침구도 드릴수있어요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/9A4AFE57E4FD631973221850E026674D79EDD2AFD8F4498DABFF032880B5E59B.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">슈퍼싱글침대 직접가져가시면 무료 침구도 드릴수있어요</h2>
# <div class="card-price ">
#         1원
#       </div>
# <div class="card-region-name">
#         서울 서초구 서초동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132069764" href="/articles/132069764">
# <div class="card-photo ">
# <img alt="자전거 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/dc458a3af756d14b7b1d1f058d0e7dc5a55b61d78f7b99ce0c7f07be47ef92c6.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">자전거 팝니다</h2>
# <div class="card-price ">
#         30,000원
#       </div>
# <div class="card-region-name">
#         경기도 용인시 수지구 동천동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 14
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132145545" href="/articles/132145545">
# <div class="card-photo ">
# <img alt="스팸입니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/8579a1bdd8261503ca79aabc41df548223352e27699cdd4c700e997f453d929b.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스팸입니다</h2>
# <div class="card-price ">
#         10,000원
#       </div>
# <div class="card-region-name">
#         부산 부산진구 양정동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="131957825" href="/articles/131957825">
# <div class="card-photo ">
# <img alt="위닉스 플라즈마웨이브 제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202009/09da5d1b058377d48e7b10aa3a8540fa9ac508173bbc4df0a0f77bb3d0a8b076.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">위닉스 플라즈마웨이브 제습기</h2>
# <div class="card-price ">
#         60,000원
#       </div>
# <div class="card-region-name">
#         서울 성북구 하월곡동
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 29
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132012482" href="/articles/132012482">
# <div class="card-photo ">
# <img alt="제닉스 아레나 게이밍 의자 판매합니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/729020845afd6e97237137bf1cce40ef7ad112111b6e6ccda31663e40c86dd5d.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">제닉스 아레나 게이밍 의자 판매합니다.</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         경기도 수원시 영통구 영통동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132172074" href="/articles/132172074">
# <div class="card-photo ">
# <img alt="모시송편" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/c31d0d90cd9f4c803d04217b43e39e118a23c7c111139ac484e3c2047676582b.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">모시송편</h2>
# <div class="card-price ">
#         무료나눔
#       </div>
# <div class="card-region-name">
#         경기도 고양시 일산서구 주엽2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132033713" href="/articles/132033713">
# <div class="card-photo ">
# <img alt="체형교정 커블와이더 의자" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/45899aaa669e9d12fc063356aed9edf9d8bab877fdd0d9f826a07f5525a2f57e.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">체형교정 커블와이더 의자</h2>
# <div class="card-price ">
#         20,000원
#       </div>
# <div class="card-region-name">
#         서울 성북구 정릉제2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132058505" href="/articles/132058505">
# <div class="card-photo ">
# <img alt="스팸 추석선물세트 안 먹어서 팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/AAAA3BD82C12F8A2357D0C45CF53F4F83CAB4B1379A052029319819537CD302F.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스팸 추석선물세트 안 먹어서 팔아요</h2>
# <div class="card-price ">
#         3,500원
#       </div>
# <div class="card-region-name">
#         경기도 부천시 원종동
#       </div>
# <div class="card-counts">
# <span>
#             관심 8
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132121776" href="/articles/132121776">
# <div class="card-photo ">
# <img alt="아이패드 6세대 128g + 애플펜슬 + 케이스" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/14F99C54567706F08A190FA912A036A174EF5BDBF2B8C6767962497F32821A98.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이패드 6세대 128g + 애플펜슬 + 케이스</h2>
# <div class="card-price ">
#         600,000원
#       </div>
# <div class="card-region-name">
#         서울 성북구 정릉동
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="131949667" href="/articles/131949667">
# <div class="card-photo ">
# <img alt="만원에 가져가세요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202009/2671207cb37764d465376a2e0410a1c9955b75145fd89a9bdef0ae7dfbe5498d.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">만원에 가져가세요</h2>
# <div class="card-price ">
#         10,000원
#       </div>
# <div class="card-region-name">
#         충남 천안시 서북구 두정동
#       </div>
# <div class="card-counts">
# <span>
#             관심 14
#           </span>
#         ∙
#         <span>
#             채팅 35
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132141263" href="/articles/132141263">
# <div class="card-photo ">
# <img alt="케이블 릴선" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/cc70131ec0c8d339e21c7ce23089b5a9df8017ad3e21670607257bcac17a404a.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">케이블 릴선</h2>
# <div class="card-price ">
#         10,000원
#       </div>
# <div class="card-region-name">
#         인천 남동구 만수2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132098786" href="/articles/132098786">
# <div class="card-photo ">
# <img alt="스팸" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/9e64e723b9a77ab9ac942b012236fea761b05b4d079707795edf38983e2be2d4.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스팸</h2>
# <div class="card-price ">
#         10,000원
#       </div>
# <div class="card-region-name">
#         서울 노원구 공릉1동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132130275" href="/articles/132130275">
# <div class="card-photo ">
# <img alt="Pxg 골프옷 팝니다 " src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/D66409E878BC834E375CA3E69AF01AFAD40D7B43144FA417B1B9183B48051742.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">Pxg 골프옷 팝니다 </h2>
# <div class="card-price ">
#         80,000원
#       </div>
# <div class="card-region-name">
#         서울 강남구 도곡2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132124480" href="/articles/132124480">
# <div class="card-photo ">
# <img alt="캠핑 타프 팝니다!" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/d393a0a9d819eed2f9880028dfe9b611a1764aaf36e8c3d49c6471e2e95a95d2.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">캠핑 타프 팝니다!</h2>
# <div class="card-price ">
#         20,000원
#       </div>
# <div class="card-region-name">
#         전북 전주시 덕진구 송천동2가
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132108989" href="/articles/132108989">
# <div class="card-photo ">
# <img alt="미니 자전거" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/019636527e237989268227d4d9ef63606db12daef37855f152044b1dc19dd427.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">미니 자전거</h2>
# <div class="card-price ">
#         60,000원
#       </div>
# <div class="card-region-name">
#         경기도 용인시 수지구 상현동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132184786" href="/articles/132184786">
# <div class="card-photo ">
# <img alt="코베아 구이바다 M 5만원" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/d1e47a6929b71e035fdb3fba8b81f9fdf131ac70ade6553857abcb7a2ba6043e.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">코베아 구이바다 M 5만원</h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         제주 제주시 애월읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132087479" href="/articles/132087479">
# <div class="card-photo ">
# <img alt="자전거 판매" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/28ff7b68fd04928ac0d4b8f1f085dbd9f1ce932074b2508444945188a31f2a26.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">자전거 판매</h2>
# <div class="card-price ">
#         20,000원
#       </div>
# <div class="card-region-name">
#         경기도 화성시 동탄1동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# ...
# </div>
# <div class="card-desc">
# <h2 class="card-title">책장</h2>
# <div class="card-price blank-price">
#         -
#       </div>
# <div class="card-region-name">
#         서울 마포구 상수동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132007088" href="/articles/132007088">
# <div class="card-photo ">
# <img alt="알톤 자전거 팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/f29bc765ca0cede4af5a8033b3e02c61b067a23d8d79756253a202330a5a3446.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">알톤 자전거 팔아요</h2>
# <div class="card-price ">
#         30,000원
#       </div>
# <div class="card-region-name">
#         경기도 용인시 수지구 동천동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 14
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132043721" href="/articles/132043721">
# <div class="card-photo ">
# <img alt="옷 서랍장" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/0B0C3887DD4A21CD14912D9BC304884AA606475DF39FC613247610E1CCE7842B.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">옷 서랍장</h2>
# <div class="card-price ">
#         30,000원
#       </div>
# <div class="card-region-name">
#         부산 연제구 연산제3동
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132069818" href="/articles/132069818">
# <div class="card-photo ">
# <img alt="화분 무료드림합니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/1ed6bba060f54e42a9f8b80b0143b668cb2d8cb815eb0da7ee9f42e2e6054ad6.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">화분 무료드림합니다</h2>
# <div class="card-price ">
#         무료나눔
#       </div>
# <div class="card-region-name">
#         서울 강동구 둔촌제2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132140635" href="/articles/132140635">
# <div class="card-photo ">
# <img alt="에어팟 프로" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/849da57940bba0ee2133a8c70aa168a8028fb084d32757057e89f82e9342ea7f.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">에어팟 프로</h2>
# <div class="card-price ">
#         130,000원
#       </div>
# <div class="card-region-name">
#         경기도 시흥시 신천동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132092221" href="/articles/132092221">
# <div class="card-photo ">
# <img alt="선물세트받았는데, 스팸은 안먹어서 올려봅니당" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/D138949997A965A1031F47F4025C36ADB389913C584E3AD86CECE6E7FB6BC9B4.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">선물세트받았는데, 스팸은 안먹어서 올려봅니당</h2>
# <div class="card-price ">
#         15,000원
#       </div>
# <div class="card-region-name">
#         부산 북구 구포제3동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132010249" href="/articles/132010249">
# <div class="card-photo ">
# <img alt="나무 선반 책장" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/e36536c11cbf923477d446dfbc9bea7474d455f464513bb64467d3e237ea0010.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">나무 선반 책장</h2>
# <div class="card-price ">
#         5,000원
#       </div>
# <div class="card-region-name">
#         경기도 용인시 처인구 역북동
#       </div>
# <div class="card-counts">
# <span>
#             관심 11
#           </span>
#         ∙
#         <span>
#             채팅 14
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132192048" href="/articles/132192048">
# <div class="card-photo ">
# <img alt="카봇  장난감" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/4680BFF8CCCCD6FC5C8DF02ACC35046173994118CBC7A4DF25F2F1AAD1BE8913.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">카봇  장난감</h2>
# <div class="card-price ">
#         20,000원
#       </div>
# <div class="card-region-name">
#         경기도 고양시 일산서구 덕이동
#       </div>
# <div class="card-counts">
# <span>
#             관심 0
#           </span>
#         ∙
#         <span>
#             채팅 10
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132140177" href="/articles/132140177">
# <div class="card-photo ">
# <img alt="자전거 팝니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/1AEC7F060403D2F32F0239B26B4222E7FC74C599F373840328E0745A5DB91055.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">자전거 팝니다.</h2>
# <div class="card-price ">
#         100,000원
#       </div>
# <div class="card-region-name">
#         전북 전주시 완산구 효자4동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 10
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132195096" href="/articles/132195096">
# <div class="card-photo ">
# <img alt="스팸 8k호 선물온거 저렴하게 팔아요." src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/3bb686ac9424f5058d97f8d23e2a0e808d963acf70621cab92d0c0e45df78a8c.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스팸 8k호 선물온거 저렴하게 팔아요.</h2>
# <div class="card-price ">
#         12,000원
#       </div>
# <div class="card-region-name">
#         경기도 수원시 장안구 연무동
#       </div>
# <div class="card-counts">
# <span>
#             관심 8
#           </span>
#         ∙
#         <span>
#             채팅 9
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132172787" href="/articles/132172787">
# <div class="card-photo ">
# <img alt="버팔로 캠핑의자" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/059834a0346a75791e3a80105a0fa86a6c380cf420e553f499937ae129d7465b.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">버팔로 캠핑의자</h2>
# <div class="card-price ">
#         15,000원
#       </div>
# <div class="card-region-name">
#         충북 청주시 흥덕구 복대동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 9
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132200922" href="/articles/132200922">
# <div class="card-photo ">
# <img alt="냉동고" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/84d795aefefc1ab1b296ad88a922abf3c5f2578f6d3552a5649f29816c964a60.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">냉동고</h2>
# <div class="card-price ">
#         30,000원
#       </div>
# <div class="card-region-name">
#         제주 제주시 일도2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 9
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132065239" href="/articles/132065239">
# <div class="card-photo ">
# <img alt="자전거 삼천리 아팔란치아 " src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/593232BA11F44F244903C9FDA93D2F8E59BA252CCD12C7453AF50C9BD85DAFA3.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">자전거 삼천리 아팔란치아 </h2>
# <div class="card-price ">
#         50,000원
#       </div>
# <div class="card-region-name">
#         경기도 고양시 일산동구 식사동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132067961" href="/articles/132067961">
# <div class="card-photo ">
# <img alt="알톤 R Series 로드타입자전거" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/E3D0A0F1253A2A3FF1A6CDEFFD53137FF0BABB54E91E3A60581C89F40758B3C4.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">알톤 R Series 로드타입자전거</h2>
# <div class="card-price ">
#         80,000원
#       </div>
# <div class="card-region-name">
#         경기도 화성시 동탄2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132140749" href="/articles/132140749">
# <div class="card-photo ">
# <img alt="와플 메이커" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/b7bf3dd06bd7d73d03a6cd77534b52f06984d4f41763c671764432ae9410fffb.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">와플 메이커</h2>
# <div class="card-price ">
#         4,000원
#       </div>
# <div class="card-region-name">
#         경기도 고양시 일산서구 덕이동
#       </div>
# <div class="card-counts">
# <span>
#             관심 0
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132043491" href="/articles/132043491">
# <div class="card-photo ">
# <img alt="네스프레소 커피머신 픽시" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/ec6a74cbe06b978dc788770a10a59fc9899e9313073d93f9bb006b326ce4ffd8.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">네스프레소 커피머신 픽시</h2>
# <div class="card-price ">
#         70,000원
#       </div>
# <div class="card-region-name">
#         경기도 화성시 동탄6동
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132078053" href="/articles/132078053">
# <div class="card-photo ">
# <img alt="루이비통 에바 클러치 (정품)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/2E3A47474D5B4294DA3B38A07EEF98393A99411930A54474C5DEB8EB347B91DE.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">루이비통 에바 클러치 (정품)</h2>
# <div class="card-price ">
#         300,000원
#       </div>
# <div class="card-region-name">
#         서울 송파구 잠실동
#       </div>
# <div class="card-counts">
# <span>
#             관심 11
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article><article class="card-top ">
# <a class="card-link " data-event-label="132114297" href="/articles/132114297">
# <div class="card-photo ">
# <img alt="쌀 라면드림" src="https://dnvefa72aowie.cloudfront.net/origin/article/202010/9deb404a3219d62a802823b570b46d44a4d9265b0eb4bb6fa3f50c8119f66d53.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">쌀 라면드림</h2>
# <div class="card-price ">
#         무료나눔
#       </div>
# <div class="card-region-name">
#         경기도 평택시 소사동
#       </div>
# <div class="card-counts">
# <span>
#             관심 0
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article>
# </section>
# <section id="hot-articles-go-download">
# <h3>
#         더 구경하고 싶나요?
#     </h3>
# <p>당근마켓 앱에서 따뜻한 거래를 직접 경험해보세요!</p>
# <div id="hot-articles-download-buttons">
# <a class="download-button" href="https://itunes.apple.com/kr/app/pangyojangteo/id1018769995?l=ko&amp;ls=1&amp;mt=8" target="_blank">
# <div class="home-apple-store-bar-white"></div>
# <div class="download-text">App Store</div>
# </a> <a class="download-button" href="https://play.google.com/store/apps/details?id=com.towneers.www" target="_blank">
# <div class="home-google-play-bar-white"></div>
# <div class="download-text">Google Play</div>
# </a> </div>
# </section>
# </section>
# <script charset="utf-8" type="text/javascript">
#   function changeRegion(key, value){
#     var url_array
#     if(window.location.pathname === "/hot_articles" && window.location.href.match(/\?/)) {
#       url_array = window.location.href.split('?')[1].split(/(?:r1|&?r2)=/)
#       url_array.unshift("")
#     } else {
#       url_array = window.location.pathname.split('/')
#     }
#     var keys = { r1: 2, r2: 3, r3: 4 }
#     url_array[keys[key]] = value
#     url_array[1] = 'region'
#       if(key == 'r2' && decodeURI(url_array[2]) == "세종특별자치시") {
#         url_array[4] = value
#         url_array[3] = "_"
#       }
#     if(key == 'r1') { url_array.splice(3, 2) }
#     if(key == 'r2' && url_array[3] !== "_") { url_array.splice(4, 1) }
#     window.location.href = window.location.origin + url_array.join('/')
#   }
# </script>
# <footer id="footer">
# <div class="footer-container">
# <div class="footer-top">
# <div class="footer-logo"></div>
# <ul class="footer-list">
# <li class="footer-list-item"><a class="link-highlight" href="/trust">믿을 수 있는 중고거래</a></li>
# <li class="footer-list-item"><a class="link-highlight" href="/wv/faqs">자주 묻는 질문</a></li>
# </ul>
# <ul class="footer-list">
# <li class="footer-list-item"><a href="http://team.daangn.com" target="_blank">회사 소개</a></li>
# <li class="footer-list-item"><a class="link-highlight" href="https://ad.daangn.com/" target="_blank">광고주센터</a></li>
# <li class="footer-list-item">
# <a class="ga-click" data-event-action="hot_articles" data-event-category="town_link_from" data-event-label="footer_town" href="https://town.daangn.com" target="_blank">동네가게</a>
# </li>
# </ul>
# <ul class="footer-list policy">
# <li class="footer-list-item"><a href="https://policy.daangn.com/terms.html" target="_blank">이용약관</a></li>
# <li class="footer-list-item"><a href="https://policy.daangn.com/privacy.html" target="_blank">개인정보취급방침</a></li>
# <li class="footer-list-item"><a href="https://policy.daangn.com/location.html" target="_blank">위치기반서비스 이용약관</a></li>
# </ul>
# </div>
# <div class="footer-bottom">
# <div id="copyright">
# <ul class="copyright-list">
# <li class="copyright-list-item">고객문의 <a href="mailto:cs@daangnservice.com">cs@daangnservice.com</a></li>
# <li class="copyright-list-item">제휴문의 <a href="mailto:contact@daangn.com">contact@daangn.com</a></li>
# </ul>
# <ul class="copyright-list">
# <li class="copyright-list-item">사업자 등록번호 : 375-87-00088</li>
# <li class="copyright-list-item"><address>서울특별시 구로구 디지털로 30길 28 609호</address></li>
# </ul>
# <div class="copyright-text">©Danggeun Market Inc.</div>
# </div>
# <div id="social">
# <ul class="social-list">
# <li class="social-list-item">
# <a class="footer-social-link" href="https://www.facebook.com/daangn" target="_blank">
# <img alt="facebook" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-facebook-0563f4a93852d073b41f13b8bcabb03d47af3bb3a6755cdfedd8a73686c7f18c.svg"/>
# <span class="sr-only">facebook</span>
# </a> </li>
# <li class="social-list-item">
# <a class="footer-social-link" href="https://www.instagram.com/daangnmarket/" target="_blank">
# <img alt="instagram" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-instagram-2f6c88a461597907c114b7ce28eab053fcae791ed26417915fefb6f7c9f95756.svg"/>
# <span class="sr-only">instagram</span>
# </a> </li>
# <li class="social-list-item">
# <a class="footer-social-link" href="https://blog.naver.com/daangn" target="_blank">
# <img alt="blog" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-blog-e1b0d512d1766a6962ec5bbb5b0803d2a6a9c55ad97db5ba9eebb76013caceba.svg"/>
# <span class="sr-only">blog</span>
# </a> </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# </body>
# </html>

# %% [markdown]
# ## 실습 3
# > Totally Normael Gifts 페이지에서 Scraping 하기
# img 는 링크로 처리한다.
#
# > list 형식과 append 형식의 차이 : dataframe 만드려면 append 형식으로 해야함. pandas 는 열 별로 추출해서 붙이는 것이기 때문.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.error   import HTTPError
from urllib.error   import URLError

# %%
try:
    html = urlopen('http://www.pythonscraping.com/pages/page3.html')
except HTTPError as he :
    print('http error')
except URLError as ue :
    print('url error')
else :
    soup = BeautifulSoup(html.read() , 'html.parser')

# %% [markdown]
# ## 강사님 답안
# > 결과가 제대로 나온건지 모르겠다.

# %%
title = 0
desc  = 0
cost  = 0
img   = 0

test_data = []
for tr in table.find_all('tr'):
    if tr.find('td') :
        tds = list(tr.find_all('td'))   
    # print(tds)    
        for td in tds :    
            title = tds[0].text.strip('\n')
            desc  = tds[1].text.strip('\n')        
            cost  = tds[2].text.strip('\n')
            img_src   = tds[3].find('img')['src']
        
        test_data.append([title, desc, cost, img_src]) 

test_data

# for d in data : 
#     print(d)

with open('test.csv', 'w', encoding="utf-8") as file:       
    for idx in test_data:
        file.write('{0}, {1}, {2}, {3}\n'.format(idx[0], idx[1], idx[2], idx[3]))

# %%
# for child in soup.find('table' , {'id' : 'giftList'}).children :
#     print(child)

# 형제 태그 찾기

for child in soup.find('table' , {'id' : 'giftList'}).tr.next_siblings :
    print(child)
# Out:
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td><td>
# $10,005.00
# </td><td>
# <img src="../img/gifts/img3.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift4"><td>
# Dead Parrot
# </td><td>
# This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
# </td><td>
# $0.50
# </td><td>
# <img src="../img/gifts/img4.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift5"><td>
# Mystery Box
# </td><td>
# If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
# </td><td>
# $1.50
# </td><td>
# <img src="../img/gifts/img6.jpg"/>
# </td></tr>

# %% [markdown]
# ## 우석 답안
# > append 형식으로 dataframe 만들고 csv 파일을 생성. \n 으로 구분된 부분이 있어서
# strip 으로 분리했다.

# %%
table = soup.find('table', {'id' : 'giftList'})
table

trs = table.find_all('tr')
trs

# scraping_exec[03]
# <table> 태그의 데이터들을 가져와서 csv 파일 형식으로 만들기
import string
import pandas as pd

title = []
desc = []
cost = []
img = []

cnt = 0

for tr in trs :
    if (tr.find('td')) :
        
        tds = tr.find_all('td')
        
        title.append(tds[0].text.strip('\n'))
        desc.append(tds[1].text.strip('\n'))
        cost.append(tds[2].text.strip('\n'))
            
        for td in tds :
            if td.find('img') :
                i = td.find('img')
                src = i['src']
                img.append(src)
                img[cnt] = img[cnt].strip('\n')

        cnt += 1

        
gift_df = pd.DataFrame({
    'title' : title,
    'description' : desc,
    'cost' : cost,
    'image' : img
})

gift_df.to_csv('gift_df.csv', mode = 'w', encoding = 'utf-8')
gift_df
# Out:
#                    title                                        description  \
# 0       Vegetable Basket  This vegetable basket is the perfect gift for ...
# 1  Russian Nesting Dolls  Hand-painted by trained monkeys, these exquisi...
# 2          Fish Painting  If something seems fishy about this painting, ...
# 3            Dead Parrot  This is an ex-parrot! Or maybe he's only resting?
# 4            Mystery Box  If you love suprises, this mystery box is for ...
#
#          cost                  image
# 0      $15.00  ../img/gifts/img1.jpg
# 1  $10,000.52  ../img/gifts/img2.jpg
# 2  $10,005.00  ../img/gifts/img3.jpg
# 3       $0.50  ../img/gifts/img4.jpg
# 4       $1.50  ../img/gifts/img6.jpg

# %% [markdown]
# ## 데이터를 가져오는 방법
#
# > 기상정보 웹페이지에서 필요한 기상정보를 가져와 pandas를 이용해 표로 만들고
# csv 파일을 생성하는 작업

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.error   import HTTPError
from urllib.error   import URLError

# %%
try:
    html = urlopen('https://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168#.X21Im2gzaUm')
except HTTPError as he :
    print('http error')
except URLError as ue :
    print('url error')
else :
    soup = BeautifulSoup(html.read() , 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js">
# <head>
# <!-- Meta -->
# <meta content="width=device-width" name="viewport"/>
# <link href="http://purl.org/dc/elements/1.1/" rel="schema.DC"/><title>National Weather Service</title><meta content="National Weather Service" name="DC.title"><meta content="NOAA National Weather Service National Weather Service" name="DC.description"/><meta content="US Department of Commerce, NOAA, National Weather Service" name="DC.creator"/><meta content="" name="DC.date.created" scheme="ISO8601"/><meta content="EN-US" name="DC.language" scheme="DCTERMS.RFC1766"/><meta content="weather, National Weather Service" name="DC.keywords"/><meta content="NOAA's National Weather Service" name="DC.publisher"/><meta content="National Weather Service" name="DC.contributor"/><meta content="http://www.weather.gov/disclaimer.php" name="DC.rights"/><meta content="General" name="rating"/><meta content="index,follow" name="robots"/>
# <!-- Icons -->
# <link href="./images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <!-- CSS -->
# <link href="css/bootstrap-3.2.0.min.css" rel="stylesheet"/>
# <link href="css/bootstrap-theme-3.2.0.min.css" rel="stylesheet"/>
# <link href="css/font-awesome-4.3.0.min.css" rel="stylesheet"/>
# <link href="css/ol-4.6.4.css" rel="stylesheet" type="text/css"/>
# <link href="css/mapclick.css" rel="stylesheet" type="text/css">
# <!--[if lte IE 7]><link rel="stylesheet" type="text/css" href="css/bootstrap-ie7.css" /><![endif]-->
# <!--[if lte IE 9]><link rel="stylesheet" type="text/css" href="css/mapclick-ie.css" /><![endif]-->
# <link href="css/print.css" rel="stylesheet" type="text/css">
# <link href="css/search.css" rel="stylesheet" type="text/css">
# <!-- Javascript -->
# <script src="js/lib/modernizr-2.8.3.js" type="text/javascript"></script>
# <script src="js/lib/json3-3.3.2.min.js" type="text/javascript"></script>
# <script src="js/lib/jquery-1.11.3.min.js" type="text/javascript"></script>
# <script src="js/lib/jquery.hoverIntent-1.8.1.min.js" type="text/javascript"></script>
# <script src="js/lib/bootstrap-3.2.0.min.js" type="text/javascript"></script>
# <script src="js/lib/ol-4.6.4.js" type="text/javascript"></script>
# <!--[if lte IE 8]><script type="text/javascript" src="js/respond.min.js"></script><![endif]-->
# <script src="js/jquery.autocomplete.min.js" type="text/javascript"></script>
# <script src="js/cfisurvey/cfi.js?v2" type="text/javascript"></script>
# <script src="js/forecast.esri.js" type="text/javascript"></script>
# <script src="js/forecast.search.js" type="text/javascript"></script>
# <script src="js/forecast.openlayers.js" type="text/javascript"></script>
# <script src="js/browserSniffer.js" type="text/javascript"></script>
# <script src="js/federated-analytics.js" type="text/javascript"></script>
# <script type="javascript">
# // ForeSee Staging Embed Script v2.01
# // DO NOT MODIFY BELOW THIS LINE *****************************************
# ;(function (g) {
#   var d = document, am = d.createElement('script'), h = d.head || d.getElementsByTagName("head")[0], fsr = 'fsReady',
#   aex = {
#     "src": "//gateway.foresee.com/sites/weather-gov/production/gateway.min.js",
#     "type": "text/javascript",
#     "async": "true",
#     "data-vendor": "fs",
#     "data-role": "gateway"
#   };
#   for (var attr in aex) { am.setAttribute(attr, aex[attr]); } h.appendChild(am); g[fsr] || (g[fsr] = function () { var aT = '__' + fsr + '_stk__'; g[aT] = g[aT] || []; g[aT].push(arguments); });
# })(window);
# // DO NOT MODIFY ABOVE THIS LINE *****************************************
# </script>
# <script type="text/javascript">
#             (function (i, s, o, g, r, a, m) {
#                 i['GoogleAnalyticsObject'] = r;
#                 i[r] = i[r] || function () {
#                     (i[r].q = i[r].q || []).push(arguments)
#                 }, i[r].l = 1 * new Date();
#                 a = s.createElement(o),
#                         m = s.getElementsByTagName(o)[0];
#                 a.async = 1;
#                 a.src = g;
#                 m.parentNode.insertBefore(a, m)
#             })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#             ga('create', 'UA-40768555-1', 'weather.gov', {'sampleRate': 6});
#             ga('set', 'anonymizeIp', true);
#             ga('require', 'linkid');
#             ga('send', 'pageview');
#         </script>
# </link></link></link></meta></head>
# <body>
# <main class="container">
# <header class="row clearfix" id="page-header">
# <a class="pull-left" href="http://www.noaa.gov" id="header-noaa"><img alt="National Oceanic and Atmospheric Administration" src="/css/images/header_noaa.png"/></a>
# <a class="pull-left" href="http://www.weather.gov" id="header-nws"><img alt="National Weather Service" src="/css/images/header_nws.png"/></a>
# <a class="pull-right" href="http://www.commerce.gov" id="header-doc"><img alt="United States Department of Commerce" src="/css/images/header_doc.png"/></a>
# </header>
# <nav class="navbar navbar-default row" role="navigation">
# <div class="container-fluid">
# <div class="navbar-header">
# <button class="navbar-toggle collapsed" data-target="#top-nav" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="collapse navbar-collapse" id="top-nav">
# <ul class="nav navbar-nav">
# <li><a href="http://www.weather.gov">HOME</a></li>
# <li class="dropdown"><a class="dropdown-toggle" data-toggle="dropdown" href="http://www.weather.gov/forecastmaps">FORECAST <span class="caret"></span></a><ul class="dropdown-menu" role="menu"><li><a href="http://www.weather.gov">Local</a></li><li><a href="http://digital.weather.gov">Graphical</a></li><li><a href="http://www.aviationweather.gov/">Aviation</a></li><li><a href="http://www.nws.noaa.gov/om/marine/home.htm">Marine</a></li><li><a href="http://water.weather.gov/ahps/">Rivers and Lakes</a></li><li><a href="http://www.nhc.noaa.gov/">Hurricanes</a></li><li><a href="http://www.spc.noaa.gov/">Severe Weather</a></li><li><a href="http://www.weather.gov/fire/">Fire Weather</a></li><li><a href="https://www.esrl.noaa.gov/gmd/grad/solcalc/sunrise.html">Sun/Moon</a></li><li><a href="http://www.cpc.ncep.noaa.gov/">Long Range Forecasts</a></li><li><a href="http://www.cpc.ncep.noaa.gov">Climate Prediction</a></li><li><a href="https://www.swpc.noaa.gov/">Space Weather</a></li></ul> </li>
# <li class="dropdown"><a class="dropdown-toggle" data-toggle="dropdown" href="https://w2.weather.gov/climate">PAST WEATHER <span class="caret"></span></a><ul class="dropdown-menu" role="menu"><li><a href="https://w2.weather.gov/climate/">Past Weather</a></li><li><a href="https://w2.weather.gov/climate/">Heating/Cooling Days</a></li><li><a href="https://w2.weather.gov/climate/">Monthly Temperatures</a></li><li><a href="https://w2.weather.gov/climate/">Records</a></li><li><a href="http://aa.usno.navy.mil/">Astronomical Data</a></li></ul> </li>
# <li class="dropdown"><a class="dropdown-toggle" data-toggle="dropdown" href="http://www.weather.gov/safety">SAFETY <span class="caret"></span></a><ul class="dropdown-menu" role="menu"><li><a href="https://www.weather.gov/safety/flood">Floods</a></li><li><a href="https://www.weather.gov/safety/tsunami">Tsunamis</a></li><li><a href="https://www.weather.gov/safety/beachhazards">Beach Hazards</a></li><li><a href="https://www.weather.gov/safety/wildfire">Wildfire</a></li><li><a href="https://www.weather.gov/safety/cold">Cold</a></li><li><a href="https://www.weather.gov/safety/tornado">Tornadoes</a></li><li><a href="https://www.weather.gov/safety/fog">Fog</a></li><li><a href="https://www.weather.gov/safety/airquality">Air Quality</a></li><li><a href="https://www.weather.gov/safety/heat">Heat</a></li><li><a href="https://www.weather.gov/safety/hurricane">Hurricanes</a></li><li><a href="https://www.weather.gov/safety/lightning">Lightning</a></li><li><a href="https://www.weather.gov/safety/safeboating">Safe Boating</a></li><li><a href="https://www.weather.gov/safety/ripcurrent">Rip Currents</a></li><li><a href="https://www.weather.gov/safety/thunderstorm">Thunderstorms</a></li><li><a href="https://www.weather.gov/safety/space">Space Weather</a></li><li><a href="https://www.weather.gov/safety/heat-uv">Sun (Ultraviolet Radiation)</a></li><li><a href="http://www.weather.gov/safetycampaign">Safety Campaigns</a></li><li><a href="https://www.weather.gov/safety/wind">Wind</a></li><li><a href="https://www.weather.gov/safety/drought">Drought</a></li><li><a href="https://www.weather.gov/safety/winter">Winter Weather</a></li></ul> </li>
# <li class="dropdown"><a class="dropdown-toggle" data-toggle="dropdown" href="http://www.weather.gov/informationcenter">INFORMATION <span class="caret"></span></a><ul class="dropdown-menu" role="menu"><li><a href="http://www.weather.gov/Owlie's">Owlie's Kids Page</a></li><li><a href="http://www.weather.gov/wrn/wea">Wireless Emergency Alerts</a></li><li><a href="https://www.weather.gov/owlie/publication_brochures">Brochures</a></li><li><a href="http://www.weather.gov/wrn/">Weather-Ready Nation</a></li><li><a href="https://www.weather.gov/coop/">Cooperative Observers</a></li><li><a href="http://www.weather.gov/briefing/">Daily Briefing</a></li><li><a href="http://www.nws.noaa.gov/om/hazstats.shtml">Damage/Fatality/Injury Statistics</a></li><li><a href="http://mag.ncep.noaa.gov/">Forecast Models</a></li><li><a href="https://www.weather.gov/gis">GIS Data Portal</a></li><li><a href="https://www.weather.gov/nwr/">NOAA Weather Radio</a></li><li><a href="http://weather.gov/publications">Publications</a></li><li><a href="http://www.weather.gov/SKYWARN">SKYWARN Storm Spotters</a></li><li><a href="http://www.weather.gov/StormReady">StormReady</a></li><li><a href="https://www.weather.gov/TsunamiReady/">TsunamiReady</a></li><li><a href="https://www.weather.gov/notification/">Service Change Notices</a></li></ul> </li>
# <li class="dropdown"><a class="dropdown-toggle" data-toggle="dropdown" href="http://www.weather.gov/owlie">EDUCATION <span class="caret"></span></a><ul class="dropdown-menu" role="menu"><li><a href="https://www.weather.gov/wrn/force">Be A Force of Nature</a></li><li><a href="http://www.weather.gov/owlie">NWS Education Home</a></li></ul> </li>
# <li class="dropdown"><a class="dropdown-toggle" data-toggle="dropdown" href="http://www.weather.gov/contact-media/">NEWS <span class="caret"></span></a><ul class="dropdown-menu" role="menu"><li><a href="http://www.weather.gov/news">NWS News</a></li><li><a href="https://www.weather.gov/wrn/calendar">Events</a></li><li><a href="http://www.weather.gov/socialmedia">Social Media</a></li><li><a href="https://www.weather.gov/owlie/publication_brochures">Pubs/Brochures/Booklets </a></li><li><a href="http://www.noaa.gov/NOAA-Communications">NWS Media Contacts</a></li></ul> </li>
# <li class="dropdown"><a class="dropdown-toggle" data-toggle="dropdown" href="http://www.weather.gov/search">SEARCH <span class="caret"></span></a><ul class="dropdown-menu" role="menu"> <li><!-- Begin search code -->
# <div id="site-search">
# <form action="//search.usa.gov/search" method="get" style="margin-bottom: 0; margin-top: 0;">
# <input name="v:project" type="hidden" value="firstgov"/>
# <label for="query">Search For</label>
# <input id="query" name="query" size="12" type="text"/>
# <input type="submit" value="Go"/>
# <p>
# <input checked="checked" id="nws" name="affiliate" type="radio" value="nws.noaa.gov"/>
# <label class="search-scope" for="nws">NWS</label>
# <input id="noaa" name="affiliate" type="radio" value="noaa.gov"/>
# <label class="search-scope" for="noaa">All NOAA</label>
# </p>
# </form>
# </div>
# </li>
# </ul> </li>
# <li class="dropdown"><a class="dropdown-toggle" data-toggle="dropdown" href="http://www.weather.gov/about">ABOUT <span class="caret"></span></a><ul class="dropdown-menu" role="menu"><li><a href="http://www.weather.gov/about">About NWS</a></li><li><a href="http://www.weather.gov/organization">Organization</a></li><li><a href="https://www.weather.gov/media/wrn/NWS_Weather-Ready-Nation_Strategic_Plan_2019-2022.pdf">Strategic Plan</a></li><li><a href="https://sites.google.com/a/noaa.gov/nws-insider/">For NWS Employees</a></li><li><a href="http://www.weather.gov/international/">International</a></li><li><a href="http://www.weather.gov/organization">National Centers</a></li><li><a href="http://www.weather.gov/careers/">Careers</a></li><li><a href="http://www.weather.gov/contact">Contact Us</a></li><li><a href="https://w1.weather.gov/glossary">Glossary</a></li></ul> </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="contentArea">
# <!-- Start Forecastsearch -->
# <div class="" id="fcst-search">
# <form action="https://forecast.weather.gov/zipcity.php" class="form-inline" id="getForecast" method="get" name="getForecast" role="form">
# <div id="getfcst-body">
# <input class="form-control" id="inputstring" name="inputstring" placeholder="" type="text"/>
# <input class="btn btn-default" id="btnSearch" name="btnSearch" type="submit" value="Go"/>
# <div id="txtHelp"><a href="javascript:void(window.open('http://weather.gov/ForecastSearchHelp.html','locsearchhelp','status=0,toolbar=0,location=0,menubar=0,directories=0,resizable=1,scrollbars=1,height=500,width=530').focus());">View Location Examples</a></div>
# </div>
# <div id="txtError">
# <div id="errorNoResults" style="display:none;">Sorry, the location you searched for was not found. Please try another search.</div>
# <div id="errorMultipleResults" style="display:none">Multiple locations were found. Please select one of the following:</div>
# <div id="errorChoices" style="display:none"></div>
# <input id="btnCloseError" style="display:none" type="button" value="Close"/>
# </div>
# <div id="getfcst-head">
# <p>Your local forecast office is</p>
# <h3 id="getfcst-headOffice"></h3>
# </div>
# </form>
# </div>
# <!-- end Forecastsearch -->
# <link href="/css/topnews.css" rel="stylesheet" type="text/css"/>
# <div id="news-items">
# <div id="topnews">
# <div class="icon"><img src="/images/news-important.jpg"/></div>
# <div class="body">
# <h1 style="font-size: 11pt;">Very Warm &amp; Dry Across the West; Turning Quite Cool Over Much of the Eastern U.S.</h1>
# <p>
#             Unusually warm temperatures and continued dry conditions will again result in critical fire weather conditions over portions of California and the Plains. Over the eastern states, much cooler air will return in the wake of a strong cold front. Meanwhile, areas of heavy rainfall are expected to persist over South Florida through at least Saturday.
#             <a href="http://www.wpc.ncep.noaa.gov/discussions/hpcdiscussions.php?disc=pmdspd" target="_blank">Read More &gt;</a>
# </p>
# </div>
# </div>
# </div>
# <script type="text/javascript">(function ($) { var topnews = $("#topnews"); topnews.hide(); $.get("siteNews.php", {a:"mtr"},function(response){ if (response !== "false") topnews.replaceWith($(response)); topnews.show(); }); })(jQuery);</script><!-- PageFormat-Land -->
# <script language="javascript">document.title = $('<div/>').html('7-Day Forecast for Latitude 37.77&deg;N and Longitude 122.41&deg;W (Elev. 131 ft)').text();</script><img src="images/track_land_point.png" style="display:none;"><div class="panel panel-danger"><div class="panel-heading"><h3 class="panel-title">Hazardous Weather Conditions</h3></div><div class="panel-body"><ul><li><a class="anchor-hazards" href="showsigwx.php?warnzone=CAZ006&amp;warncounty=CAC075&amp;firewxzone=CAZ006&amp;local_place1=San Francisco CA&amp;product1=Heat+Advisory&amp;lat=37.7772&amp;lon=-122.4168" id="hazard-CAZ006-Heat+Advisory-0">Heat Advisory in effect from October 1,  11:00 AM PDT until October 1, 08:00 PM PDT</a></li></ul></div></div>
# <div id="quickLinks">
# <span class="lang-spanish"><a href="//forecast.weather.gov/MapClick.php?lat=37.7772&amp;lon=-122.4168&amp;lg=sp">En Español</a></span>
# <div class="addthis_toolbox addthis_default_style addthis-forecast">
# <a class="addthis_button_compact" href="//www.addthis.com/bookmark.php?v=250&amp;pubid=ra-5127a6364d551d04">Share</a>
# <span class="addthis_separator">|</span>
# <a class="addthis_button_preferred_1"></a>
# <a class="addthis_button_preferred_2"></a>
# <a class="addthis_button_preferred_3"></a>
# <a class="addthis_button_preferred_4"></a>
# <a class="addthis_button_preferred_5"></a>
# </div>
# <script type="text/javascript">
# 		var addthis_config = addthis_config || {data_track_addressbar:true, pubid: 'xa-4b05b2d91f18c9cc'};
# 	    $(document).ready(function(){
# 			jQuery.ajax({
# 				url: "//s7.addthis.com/js/300/addthis_widget.js#async=1",
# 				dataType: "script",
# 				cache: false
# 			});
# 	    });
# 	</script>
# </div>
# <!-- Current Conditions -->
# <div class="panel panel-default" id="current-conditions">
# <!-- Current Conditions header row -->
# <div class="panel-heading">
# <div>
# <b>Current conditions at</b>
# <h2 class="panel-title">SAN FRANCISCO DOWNTOWN (SFOC1)</h2>
# <span class="smallTxt"><b>Lat: </b>37.77056°N<b>Lon: </b>122.42694°W<b>Elev: </b>150ft.</span>
# </div>
# </div>
# <div class="panel-body" id="current-conditions-body">
# <!-- Graphic and temperatures -->
# <div class="pull-left" id="current_conditions-summary">
# <p class="myforecast-current">NA</p>
# <p class="myforecast-current-lrg">65°F</p>
# <p class="myforecast-current-sm">18°C</p>
# </div>
# <div class="pull-left" id="current_conditions_detail">
# <table>
# <tr>
# <td class="text-right"><b>Humidity</b></td>
# <td>65%</td>
# </tr>
# <tr>
# <td class="text-right"><b>Wind Speed</b></td>
# <td>NA NA MPH</td>
# </tr>
# <tr>
# <td class="text-right"><b>Barometer</b></td>
# <td>NA</td>
# </tr>
# <tr>
# <td class="text-right"><b>Dewpoint</b></td>
# <td>53°F (12°C)</td>
# </tr>
# <tr>
# <td class="text-right"><b>Visibility</b></td>
# <td>NA</td>
# </tr>
# <tr>
# <td class="text-right"><b>Last update</b></td>
# <td>
#                 01 Oct 12:43 AM PDT            </td>
# </tr>
# </table>
# </div>
# <div id="current_conditions_station">
# <div class="current-conditions-extra">
# <!-- Right hand section -->
# <p class="moreInfo"><b>More Information:</b></p><p><a href="https://www.weather.gov/mtr" id="localWFO" title="San Francisco Bay Area/Monterey, CA"><span class="hideText">Local</span> Forecast Office</a><a href="https://www.weather.gov/wrh/LocalWeather?zone=CAZ006" id="moreWx">More Local Wx</a><a href="https://www.wrh.noaa.gov/mesowest/getobext.php?wfo=mtr&amp;sid=SFOC1&amp;num=72&amp;raw=0">3 Day History</a><a href="//mobile.weather.gov/index.php?lat=37.7772&amp;lon=-122.4168&amp;unit=0&amp;lg=english" id="mobileWxLink">Mobile Weather</a><a href="MapClick.php?lat=37.7772&amp;lon=-122.4168&amp;unit=0&amp;lg=english&amp;FcstType=graphical" id="wxGraph">Hourly <span class="hideText">Weather </span>Forecast</a></p> </div>
# <!-- /current_conditions_station -->
# </div>
# <!-- /current-conditions-body -->
# </div>
# <!-- /Current Conditions -->
# </div>
# <!-- 7-Day Forecast -->
# <div class="panel panel-default" id="seven-day-forecast">
# <div class="panel-heading">
# <b>Extended Forecast for</b>
# <h2 class="panel-title">
# 	    	    San Francisco CA	</h2>
# </div>
# <div class="panel-body" id="seven-day-forecast-body">
# <div id="seven-day-forecast-container"><div id="headline-container"><div id="headline-info" onclick="$('#headline-detail').toggle(); $('#headline-detail-now').hide()" style="margin-top: 5px"><div id="headline-detail"><div>Heat Advisory October 1, 11:00am until October 1, 08:00pm</div></div><span class="fa fa-info-circle"></span>Click here for hazard details and duration</div><div class="headline-bar headline-advisory " style="top: 40px; left: 176px; height: 125px; width: 93px">
# <div class="headline-title">Heat Advisory</div>
# </div></div><ul class="list-unstyled" id="seven-day-forecast-list" style="padding-top: 60px"><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Overnight<br/><br/></p>
# <p><img alt="Overnight: Widespread haze. Patchy smoke. Partly cloudy, with a low around 60. West southwest wind around 7 mph. " class="forecast-icon" src="newimages/medium/hz.png" title="Overnight: Widespread haze. Patchy smoke. Partly cloudy, with a low around 60. West southwest wind around 7 mph. "/></p><p class="short-desc">Haze</p><p class="temp temp-low">Low: 60 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Thursday<br/><br/></p>
# <p><img alt="Thursday: Widespread haze before 9am. Patchy smoke before 9am. Sunny, with a high near 92. Light southwest wind becoming west 5 to 10 mph in the afternoon. " class="forecast-icon" src="DualImage.php?i=hz&amp;j=few" title="Thursday: Widespread haze before 9am. Patchy smoke before 9am. Sunny, with a high near 92. Light southwest wind becoming west 5 to 10 mph in the afternoon. "/></p><p class="short-desc">Haze then<br/>Sunny</p><p class="temp temp-high">High: 92 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Thursday<br/>Night</p>
# <p><img alt="Thursday Night: Mostly clear, with a low around 62. West wind 8 to 13 mph. " class="forecast-icon" src="newimages/medium/nfew.png" title="Thursday Night: Mostly clear, with a low around 62. West wind 8 to 13 mph. "/></p><p class="short-desc">Mostly Clear</p><p class="temp temp-low">Low: 62 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Friday<br/><br/></p>
# <p><img alt="Friday: Sunny, with a high near 82. West wind 5 to 15 mph, with gusts as high as 18 mph. " class="forecast-icon" src="newimages/medium/few.png" title="Friday: Sunny, with a high near 82. West wind 5 to 15 mph, with gusts as high as 18 mph. "/></p><p class="short-desc">Sunny</p><p class="temp temp-high">High: 82 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Friday<br/>Night</p>
# <p><img alt="Friday Night: Mostly clear, with a low around 59. West wind 11 to 15 mph, with gusts as high as 20 mph. " class="forecast-icon" src="newimages/medium/nfew.png" title="Friday Night: Mostly clear, with a low around 59. West wind 11 to 15 mph, with gusts as high as 20 mph. "/></p><p class="short-desc">Mostly Clear</p><p class="temp temp-low">Low: 59 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Saturday<br/><br/></p>
# <p><img alt="Saturday: Mostly sunny, with a high near 74." class="forecast-icon" src="newimages/medium/sct.png" title="Saturday: Mostly sunny, with a high near 74."/></p><p class="short-desc">Mostly Sunny</p><p class="temp temp-high">High: 74 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Saturday<br/>Night</p>
# <p><img alt="Saturday Night: Mostly cloudy, with a low around 57." class="forecast-icon" src="newimages/medium/nbkn.png" title="Saturday Night: Mostly cloudy, with a low around 57."/></p><p class="short-desc">Mostly Cloudy</p><p class="temp temp-low">Low: 57 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Sunday<br/><br/></p>
# <p><img alt="Sunday: Partly sunny, with a high near 70." class="forecast-icon" src="newimages/medium/bkn.png" title="Sunday: Partly sunny, with a high near 70."/></p><p class="short-desc">Partly Sunny</p><p class="temp temp-high">High: 70 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Sunday<br/>Night</p>
# <p><img alt="Sunday Night: Mostly cloudy, with a low around 57." class="forecast-icon" src="newimages/medium/nbkn.png" title="Sunday Night: Mostly cloudy, with a low around 57."/></p><p class="short-desc">Mostly Cloudy</p><p class="temp temp-low">Low: 57 °F</p></div></li></ul></div>
# <script type="text/javascript">
# // equalize forecast heights
# $(function () {
# 	var maxh = 0;
# 	$(".forecast-tombstone .short-desc").each(function () {
# 		var h = $(this).height();
# 		if (h > maxh) { maxh = h; }
# 	});
# 	$(".forecast-tombstone .short-desc").height(maxh);
# });
# </script> </div>
# </div>
# <!-- Everything between 7-Day Forecast and Footer goes in this row -->
# <div class="row" id="floatingDivs">
# <!-- Everything on the left-hand side -->
# <div class="col-md-7 col-lg-8">
# <!-- Detailed Forecast -->
# <div class="panel panel-default" id="detailed-forecast">
# <div class="panel-heading">
# <h2 class="panel-title">Detailed Forecast</h2>
# </div>
# <div class="panel-body" id="detailed-forecast-body">
# <div class="row row-odd row-forecast"><div class="col-sm-2 forecast-label"><b>Overnight</b></div><div class="col-sm-10 forecast-text">Widespread haze. Patchy smoke. Partly cloudy, with a low around 60. West southwest wind around 7 mph. </div></div><div class="row row-even row-forecast"><div class="col-sm-2 forecast-label"><b>Thursday</b></div><div class="col-sm-10 forecast-text">Widespread haze before 9am. Patchy smoke before 9am. Sunny, with a high near 92. Light southwest wind becoming west 5 to 10 mph in the afternoon. </div></div><div class="row row-odd row-forecast"><div class="col-sm-2 forecast-label"><b>Thursday Night</b></div><div class="col-sm-10 forecast-text">Mostly clear, with a low around 62. West wind 8 to 13 mph. </div></div><div class="row row-even row-forecast"><div class="col-sm-2 forecast-label"><b>Friday</b></div><div class="col-sm-10 forecast-text">Sunny, with a high near 82. West wind 5 to 15 mph, with gusts as high as 18 mph. </div></div><div class="row row-odd row-forecast"><div class="col-sm-2 forecast-label"><b>Friday Night</b></div><div class="col-sm-10 forecast-text">Mostly clear, with a low around 59. West wind 11 to 15 mph, with gusts as high as 20 mph. </div></div><div class="row row-even row-forecast"><div class="col-sm-2 forecast-label"><b>Saturday</b></div><div class="col-sm-10 forecast-text">Mostly sunny, with a high near 74.</div></div><div class="row row-odd row-forecast"><div class="col-sm-2 forecast-label"><b>Saturday Night</b></div><div class="col-sm-10 forecast-text">Mostly cloudy, with a low around 57.</div></div><div class="row row-even row-forecast"><div class="col-sm-2 forecast-label"><b>Sunday</b></div><div class="col-sm-10 forecast-text">Partly sunny, with a high near 70.</div></div><div class="row row-odd row-forecast"><div class="col-sm-2 forecast-label"><b>Sunday Night</b></div><div class="col-sm-10 forecast-text">Mostly cloudy, with a low around 57.</div></div><div class="row row-even row-forecast"><div class="col-sm-2 forecast-label"><b>Monday</b></div><div class="col-sm-10 forecast-text">Partly sunny, with a high near 71.</div></div><div class="row row-odd row-forecast"><div class="col-sm-2 forecast-label"><b>Monday Night</b></div><div class="col-sm-10 forecast-text">Mostly cloudy, with a low around 56.</div></div><div class="row row-even row-forecast"><div class="col-sm-2 forecast-label"><b>Tuesday</b></div><div class="col-sm-10 forecast-text">Partly sunny, with a high near 72.</div></div><div class="row row-odd row-forecast"><div class="col-sm-2 forecast-label"><b>Tuesday Night</b></div><div class="col-sm-10 forecast-text">Mostly cloudy, with a low around 58.</div></div><div class="row row-even row-forecast"><div class="col-sm-2 forecast-label"><b>Wednesday</b></div><div class="col-sm-10 forecast-text">Partly sunny, with a high near 71.</div></div> </div>
# </div>
# <!-- /Detailed Forecast -->
# <!-- Additional Forecasts and Information -->
# <div class="panel panel-default" id="additional_forecasts">
# <div class="panel-heading">
# <h2 class="panel-title">Additional Forecasts and Information</h2>
# </div>
# <div class="panel-body" id="additional-forecasts-body">
# <p class="myforecast-location"><a href="MapClick.php?zoneid=CAZ006">Zone Area Forecast for San Francisco County, CA</a></p>
# <!-- First nine-ten links -->
# <div id="linkBlockContainer">
# <div class="linkBlock">
# <ul class="list-unstyled">
# <li><a href="//forecast.weather.gov/product.php?site=MTR&amp;issuedby=MTR&amp;product=AFD&amp;format=CI&amp;version=1&amp;glossary=1">Forecast Discussion</a></li>
# <li><a href="MapClick.php?lat=37.7772&amp;lon=-122.4168&amp;unit=0&amp;lg=english&amp;FcstType=text&amp;TextType=2">Printable Forecast</a></li>
# <li><a href="MapClick.php?lat=37.7772&amp;lon=-122.4168&amp;unit=0&amp;lg=english&amp;FcstType=text&amp;TextType=1">Text Only Forecast</a></li>
# </ul>
# </div>
# <div class="linkBlock">
# <ul class="list-unstyled">
# <li><a href="MapClick.php?lat=37.7772&amp;lon=-122.4168&amp;unit=0&amp;lg=english&amp;FcstType=graphical">Hourly Weather Forecast</a></li>
# <li><a href="MapClick.php?lat=37.7772&amp;lon=-122.4168&amp;unit=0&amp;lg=english&amp;FcstType=digital">Tabular Forecast</a></li>
# <!-- <li><a href="afm/PointClick.php?lat=37.7772&lon=-122.4168">Quick Forecast</a></li> -->
# </ul>
# </div>
# <div class="linkBlock">
# <ul class="list-unstyled">
# <li><a href="//weather.gov/aq/probe_aq_data.php?latitude=37.7772&amp;longitude=-122.4168">Air Quality Forecasts</a></li>
# <li><a href="MapClick.php?lat=37.7772&amp;lon=-122.4168&amp;FcstType=text&amp;unit=1&amp;lg=en">International System of Units</a></li>
# <li><a href="//www.wrh.noaa.gov/forecast/wxtables/index.php?lat=37.7772&amp;lon=-122.4168">Forecast Weather Table Interface</a></li>
# </ul>
# </div>
# <!-- /First nine-ten links -->
# <!-- Additional links -->
# <div class="linkBlock"><ul class="list-unstyled"><li><a href="http://www.wrh.noaa.gov/mtr/versprod.php?pil=RR8&amp;sid=RSA" target="_self">Hourly River Stages</a></li><li><a href="http://www.wrh.noaa.gov/mtr/versprod.php?pil=RR5&amp;sid=RSA" target="_self">Hourly Rainfall</a></li></ul></div><div class="linkBlock"><ul class="list-unstyled"><li><a href="http://www.wrh.noaa.gov/mtr/wxlinks.php" target="_self">NWS Office Map</a></li><li><a href="http://www.wrh.noaa.gov/mtr/wx_calculator.php" target="_self">Weather Calculator</a></li></ul></div><div class="linkBlock"><ul class="list-unstyled"><li><a href="http://www.nws.noaa.gov/wtf/udaf/area/?site=mtr" target="_self">User Defined Area</a></li></ul></div>
# </div> <!-- /linkBlockContainer -->
# </div><!-- /additional-forecasts-body-->
# </div> <!-- /additional_forecasts -->
# </div> <!-- /Everything on the left-hand side -->
# <!-- right-side-data -->
# <div class="col-md-5 col-lg-4" id="right-side-data">
# <div id="mapAndDescriptionArea">
# <!-- openlayer map -->
# <style>
# #custom-search{
# display: block;
# position: relative;
# z-index: 50;
# top: 52px;
# left: 60px;
# }
# #esri-geocoder-search{
# display: block;
# position: relative;
# z-index: 50;
# top: 52px;
# left: 60px;
# }
# #emap{
# margin-top:15px;
# cursor:pointer;
# height:370px;
# width:100%;
# border: 1px solid #ccc;
# border-radius: 3px;
# }
# #switch-basemap-container{
# }
# #basemap-selection-form ul{
# list-style: none;
#  margin: 0px;
# }
# #basemap-selection-form li{
# float: left;
# }
# .disclaimer{
# margin-top:350px;
# margin-left: 5px;
# z-index: 100;
# position: absolute;
# text-transform: none;
# }
# .esriAttributionLastItem{
# text-transform: none;
# }
# .esriSimpleSlider div{
# height:22px;
# line-height:20px;
# width:20px;
# }
# #point-forecast-map-label {
# text-align:center;
# font-weight:bold;
# color:black;
# }
# @media (max-width: 767px) {
# #emap{
# margin-top:.5em;
# height:270px;
# }
# .disclaimer{
# margin-top:250px;
# }
# }
# </style>
# <!-- forecast-map -->
# <div class="point-forecast-map">
# <div class="point-forecast-map-header text-center">
# <div id="toolbar">
# <div id="switch-basemap-container">
# <div id="basemap-selection-form" title="Choose a Basemap">
# <div id="basemap-menu">
# <select autocomplete="off" id="basemap-selected" name="basemap-selected" title="Basemap Dropdown Menu">
# <option value="none">Select Basemap</option>
# <option selected="" value="topo">Topographic</option>
# <option value="streets">Streets</option>
# <option value="satellite">Satellite</option>
# <option value="ocean">Ocean</option>
# </select>
# </div>
# </div>
# <div id="point-forecast-map-label">
#                     Click Map For Forecast
#                 </div>
# </div><!-- //#switch-basemap-container -->
# <div style="clear:both;"></div>
# </div><!-- //#toolbar -->
# </div><!-- //.point-forecast-map-header -->
# <div id="emap">
# <noscript><center><br/><br/><b>Map function requires Javascript and a compatible browser.</b></center></noscript>
# <div class="disclaimer"><a href="http://www.weather.gov/disclaimer#esri">Disclaimer</a></div>
# </div><!-- //#emap -->
# <div class="point-forecast-map-footer">
# <img alt="Map Legend" height="16" src="./images/wtf/maplegend_forecast-area.gif" width="100"/>
# </div><!-- //.point-forecast-map-footer -->
# </div> <!-- //.point-forecast-map -->
# <!-- //forecast-map -->
# <!-- //openlayer map -->
# <!-- About this Forecast -->
# <div id="about_forecast">
# <div class="fullRow">
# <div class="left">Point Forecast:</div>
# <div class="right">San Francisco CA<br/> 37.77°N 122.41°W (Elev. 131 ft)</div>
# </div>
# <div class="fullRow">
# <div class="left"><a href="//www.weather.gov/glossary/index.php?word=Last+update" target="_blank">Last Update</a>: </div>
# <div class="right">7:34 pm PDT Sep 30, 2020</div>
# </div>
# <div class="fullRow">
# <div class="left"><a href="//www.weather.gov/glossary/index.php?word=forecast+valid+for" target="_blank">Forecast Valid</a>: </div>
# <div class="right">1am PDT Oct 1, 2020-6pm PDT Oct 7, 2020</div>
# </div>
# <div class="fullRow">
# <div class="left"> </div>
# <div class="right"><a href="https://forecast.weather.gov/product.php?site=MTR&amp;issuedby=MTR&amp;product=AFD&amp;format=CI&amp;version=1&amp;glossary=1">Forecast Discussion</a></div>
# </div>
# <div class="fullRow">
# <div class="left"> </div>
# <div class="right">
# <a href="MapClick.php?lat=37.7772&amp;lon=-122.4168&amp;unit=0&amp;lg=english&amp;FcstType=kml"><img alt="Get as KML" height="17" src="/images/wtf/kml_badge.png" width="45"/></a>
# <a href="MapClick.php?lat=37.7772&amp;lon=-122.4168&amp;unit=0&amp;lg=english&amp;FcstType=dwml"><img alt="Get as XML" height="17" src="/images/wtf/xml_badge.png" width="45"/></a>
# </div>
# </div>
# </div>
# <!-- /About this Forecast -->
# </div>
# <!--additionalForecast-->
# <div class="panel panel-default" id="additionalForecast">
# <div class="panel-heading">
# <h2 class="panel-title">Additional Resources</h2>
# </div>
# <div class="panel-body">
# <!-- Radar & Satellite Images -->
# <div class="subItem" id="radar">
# <h4>Radar &amp; Satellite Image</h4>
# <a href="//radar.weather.gov/radar.php?rid=mux&amp;product=N0R&amp;overlay=11101111&amp;loop=no"><img alt="Link to Local Radar Data" class="radar-thumb" src="//radar.weather.gov/Thumbs/MUX_Thumb.gif" title="Link to Local Radar Data"/></a> <a href="https://www.star.nesdis.noaa.gov/GOES/sector.php?sat=G17§or=psw"><img alt="Link to Satellite Data" class="satellite-thumb" src="https://cdn.star.nesdis.noaa.gov/GOES17/ABI/SECTOR/psw/GEOCOLOR/600x600.jpg" title="Link to Satellite Data"/></a> </div>
# <!-- /Radar & Satellite Images -->
# <!-- Hourly Weather Forecast -->
# <div class="subItem" id="feature">
# <h4>Hourly Weather Forecast</h4>
# <a href="MapClick.php?lat=37.7772&amp;lon=-122.4168&amp;unit=0&amp;lg=english&amp;FcstType=graphical"><img class="img-responsive" src="newimages/medium/hourlyweather.png"/></a>
# </div>
# <!-- /Hourly Weather Forecast -->
# <!-- NDFD -->
# <div class="subItem" id="NDFD">
# <h4>National Digital Forecast Database</h4>
# <div class="one-sixth-first"><a href="//graphical.weather.gov/sectors/pacsouthwest.php?element=MaxT"><img alt="National Digital Forecast Database Maximum Temperature Forecast" border="0" height="150" src="//graphical.weather.gov/images/thumbnail/latest_MaxMinT_pacsouthwest_thumbnail.png" title="National Digital Forecast Database Maximum Temperature Forecast" width="147"/></a>
# <p><a href="//graphical.weather.gov/sectors/pacsouthwest.php?element=MaxT">High Temperature</a></p></div><div class="one-sixth-first"><a href="//graphical.weather.gov/sectors/pacsouthwest.php?element=Wx"><img alt="National Digital Forecast Database Weather Element Forecast" border="0" height="150" src="//graphical.weather.gov/images/thumbnail/latest_Wx_pacsouthwest_thumbnail.png" title="National Digital Forecast Database Weather Element Forecast" width="147"/></a>
# <p><a href="//graphical.weather.gov/sectors/pacsouthwest.php?element=Wx">Chance of Precipitation</a></p></div> </div>
# <!-- /NDFD -->
# </div>
# </div>
# <!-- /additionalForecast -->
# </div>
# <!-- /col-md-4 -->
# <!-- /right-side-data -->
# <script language="javascript">$( document ).ready(function() { load_openlayers_map('', '', '', '{"centroid_lat":"37.7772","centroid_lon":"-122.4168","lat1":"37.7595","lon1":"-122.4205","lat2":"37.781","lon2":"-122.426","lat3":"37.7855","lon3":"-122.3985","lat4":"37.764","lon4":"-122.393"}') });</script></div>
# <!-- /row  -->
# </img></div>
# <!-- /PageFormat-Land -->
# </main></body></html>
# <footer>
# <div class="sitemap-content row" id="sitemap">
# <div class="col-xs-12">
# <div class="sitemap-columns">
# <div class="sitemap-section">
# <div class="panel-heading">
# <a class="sitemap-section-heading" href=" http://www.nws.noaa.gov/climate/">PAST WEATHER</a>
# <button class="menu-toggle pull-right" data-target="#sitemap-1" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle menu</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="sitemap-section-body panel-body collapsable collapse" id="sitemap-1">
# <ul class="list-unstyled">
# <li><a href=" http://www.cpc.ncep.noaa.gov/products/MD_index.shtml">Climate Monitoring </a></li>
# <li><a href="https://w2.weather.gov/climate/">Past Weather </a></li>
# <li><a href=" http://www.nws.noaa.gov/climate/">Monthly Temps </a></li>
# <li><a href=" http://www.nws.noaa.gov/climate/">Records </a></li>
# <li><a href="https://www.esrl.noaa.gov/gmd/grad/solcalc/sunrise.html">Astronomical Data </a></li>
# <li><a href="https://www.climate.gov/maps-data/dataset/past-weather-zip-code-data-table">Certified Weather Data </a></li>
# </ul>
# </div>
# </div>
# <div class="sitemap-section">
# <div class="panel-heading">
# <a class="sitemap-section-heading" href="http://alerts.weather.gov">ACTIVE ALERTS</a>
# <button class="menu-toggle pull-right" data-target="#sitemap-2" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle menu</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="sitemap-section-body panel-body collapsable collapse" id="sitemap-2">
# <ul class="list-unstyled">
# <li><a href=" http://alerts.weather.gov">Warnings By State</a></li>
# <li><a href=" http://www.wpc.ncep.noaa.gov/ww.shtml">Excessive Rainfall and Winter Weather Forecasts</a></li>
# <li><a href="http://water.weather.gov/ahps/?current_color=flood&amp;current_type=all&amp;fcst_type=obs&amp;conus_map=d_map">River Flooding </a></li>
# <li><a href=" http://www.weather.gov">Latest Warnings</a></li>
# <li><a href=" http://www.spc.noaa.gov/products/outlook/">Thunderstorm/Tornado Outlook </a></li>
# <li><a href=" http://www.nhc.noaa.gov/">Hurricanes </a></li>
# <li><a href=" http://www.spc.noaa.gov/products/fire_wx/">Fire Weather Outlooks </a></li>
# <li><a href=" http://www.cpc.ncep.noaa.gov/products/stratosphere/uv_index/uv_alert.shtml">UV Alerts </a></li>
# <li><a href=" http://www.drought.gov/">Drought </a></li>
# <li><a href="http://www.swpc.noaa.gov/products/alerts-watches-and-warnings">Space Weather </a></li>
# <li><a href=" http://www.nws.noaa.gov/nwr/">NOAA Weather Radio </a></li>
# <li><a href=" http://alerts.weather.gov/">NWS CAP Feeds </a></li>
# </ul>
# </div>
# </div>
# <div class="sitemap-section">
# <div class="panel-heading">
# <a class="sitemap-section-heading" href="http://www.weather.gov/current">CURRENT CONDITIONS</a>
# <button class="menu-toggle pull-right" data-target="#sitemap-3" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle menu</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="sitemap-section-body panel-body collapsable collapse" id="sitemap-3">
# <ul class="list-unstyled">
# <li><a href=" http://www.weather.gov/Radar">Radar </a></li>
# <li><a href="http://www.cpc.ncep.noaa.gov/products/monitoring_and_data/">Climate Monitoring </a></li>
# <li><a href=" http://water.weather.gov/ahps/">River Levels </a></li>
# <li><a href=" http://water.weather.gov/precip/">Observed Precipitation </a></li>
# <li><a href="https://www.wpc.ncep.noaa.gov/sfc/sfcobs/sfcobs.shtml">Surface Weather </a></li>
# <li><a href="http://www.spc.noaa.gov/obswx/maps/">Upper Air </a></li>
# <li><a href=" http://www.ndbc.noaa.gov/">Marine and Buoy Reports </a></li>
# <li><a href="http://www.nohrsc.noaa.gov/interactive/html/map.html">Snow Cover </a></li>
# <li><a href=" http://www.weather.gov/satellite">Satellite </a></li>
# <li><a href=" http://www.swpc.noaa.gov/">Space Weather </a></li>
# <li><a href="http://www.weather.gov/pr">International Observations</a></li>
# </ul>
# </div>
# </div>
# <div class="sitemap-section">
# <div class="panel-heading">
# <a class="sitemap-section-heading" href="http://weather.gov/forecastmaps">FORECAST</a>
# <button class="menu-toggle pull-right" data-target="#sitemap-4" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle menu</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="sitemap-section-body panel-body collapsable collapse" id="sitemap-4">
# <ul class="list-unstyled">
# <li><a href=" http://www.weather.gov/">Local Forecast </a></li>
# <li><a href="http://www.weather.gov/pr">International Forecasts</a></li>
# <li><a href=" http://www.spc.noaa.gov/">Severe Weather </a></li>
# <li><a href=" http://www.wpc.ncep.noaa.gov/">Current Outlook Maps </a></li>
# <li><a href="http://www.cpc.ncep.noaa.gov/products/Drought">Drought </a></li>
# <li><a href="http://www.weather.gov/fire">Fire Weather </a></li>
# <li><a href=" http://www.wpc.ncep.noaa.gov/">Fronts/Precipitation Maps </a></li>
# <li><a href=" http://www.nws.noaa.gov/forecasts/graphical/">Current Graphical Forecast Maps </a></li>
# <li><a href="http://water.weather.gov/ahps/forecasts.php">Rivers </a></li>
# <li><a href="https://www.weather.gov/marine/">Marine </a></li>
# <li><a href="https://ocean.weather.gov/marine_areas.php">Offshore and High Seas</a></li>
# <li><a href=" http://www.nhc.noaa.gov/">Hurricanes </a></li>
# <li><a href=" http://aviationweather.gov">Aviation Weather </a></li>
# <li><a href="http://www.cpc.ncep.noaa.gov/products/OUTLOOKS_index.shtml">Climatic Outlook </a></li>
# </ul>
# </div>
# </div>
# <div class="sitemap-section">
# <div class="panel-heading">
# <a class="sitemap-section-heading" href="http://www.weather.gov/informationcenter">INFORMATION CENTER</a>
# <button class="menu-toggle pull-right" data-target="#sitemap-5" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle menu</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="sitemap-section-body panel-body collapsable collapse" id="sitemap-5">
# <ul class="list-unstyled">
# <li><a href=" http://www.spaceweather.gov">Space Weather </a></li>
# <li><a href="http://www.weather.gov/briefing/">Daily Briefing </a></li>
# <li><a href=" http://www.nws.noaa.gov/om/marine/home.htm">Marine </a></li>
# <li><a href="http://www.nws.noaa.gov/climate">Climate </a></li>
# <li><a href="http://www.weather.gov/fire">Fire Weather </a></li>
# <li><a href=" http://www.aviationweather.gov/">Aviation </a></li>
# <li><a href="http://mag.ncep.noaa.gov/">Forecast Models </a></li>
# <li><a href="http://water.weather.gov/ahps/">Water </a></li>
# <li><a href="https://www.weather.gov/gis/">GIS</a></li>
# <li><a href=" http://www.nws.noaa.gov/om/coop/">Cooperative Observers </a></li>
# <li><a href="https://www.weather.gov/skywarn/">Storm Spotters </a></li>
# <li><a href="http://www.tsunami.gov">Tsunami Warning System</a></li>
# <li><a href="http://water.noaa.gov/">National Water Center</a></li>
# <li><a href="http://www.weather.gov/pr">International Weather</a></li>
# </ul>
# </div>
# </div>
# <div class="sitemap-section">
# <div class="panel-heading">
# <a class="sitemap-section-heading" href="http://weather.gov/safety">WEATHER SAFETY</a>
# <button class="menu-toggle pull-right" data-target="#sitemap-6" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle menu</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="sitemap-section-body panel-body collapsable collapse" id="sitemap-6">
# <ul class="list-unstyled">
# <li><a href="http://www.weather.gov/nwr/">NOAA Weather Radio</a></li>
# <li><a href="http://www.weather.gov/stormready/">StormReady</a></li>
# <li><a href="http://www.nws.noaa.gov/om/heat/index.shtml">Heat </a></li>
# <li><a href="https://www.weather.gov/safety/lightning">Lightning </a></li>
# <li><a href=" http://www.nhc.noaa.gov/prepare/">Hurricanes </a></li>
# <li><a href="http://www.nws.noaa.gov/om/thunderstorm/">Thunderstorms </a></li>
# <li><a href="https://www.weather.gov/safety/tornado">Tornadoes </a></li>
# <li><a href="https://www.weather.gov/safety/ripcurrent">Rip Currents </a></li>
# <li><a href="https://www.weather.gov/safety/flood">Floods </a></li>
# <li><a href="https://www.weather.gov/safety/tsunami">Tsunamis</a></li>
# <li><a href="https://www.weather.gov/tsunamiready/">TsunamiReady</a></li>
# <li><a href=" http://www.weather.gov/om/winter/index.shtml">Winter Weather </a></li>
# <li><a href="http://www.nws.noaa.gov/om/heat/uv.shtml">Ultra Violet Radiation </a></li>
# <li><a href=" http://www.weather.gov/airquality/">Air Quality </a></li>
# <li><a href=" http://www.weather.gov/om/hazstats.shtml">Damage/Fatality/Injury Statistics </a></li>
# <li><a href=" http://www.redcross.org/">Red Cross </a></li>
# <li><a href=" http://www.fema.gov/">Federal Emergency Management Agency (FEMA) </a></li>
# <li><a href=" http://www.weather.gov/om/brochures.shtml">Brochures </a></li>
# <li><a href="http://www.nws.noaa.gov/os/marine/safeboating/">Safe Boating</a></li>
# </ul>
# </div>
# </div>
# <div class="sitemap-section">
# <div class="panel-heading">
# <a class="sitemap-section-heading" href="http://weather.gov/news">NEWS</a>
# <button class="menu-toggle pull-right" data-target="#sitemap-7" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle menu</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="sitemap-section-body panel-body collapsable collapse" id="sitemap-7">
# <ul class="list-unstyled">
# <li><a href=" http://weather.gov/news">Newsroom</a></li>
# <li><a href=" http://weather.gov/socialmedia">Social Media </a></li>
# <li><a href="http://www.nws.noaa.gov/com/weatherreadynation/calendar.html">Events</a></li>
# <li><a href=" http://www.weather.gov/om/brochures.shtml">Pubs/Brochures/Booklets </a></li>
# </ul>
# </div>
# </div>
# <div class="sitemap-section">
# <div class="panel-heading">
# <a class="sitemap-section-heading" href="http://weather.gov/owlie">EDUCATION</a>
# <button class="menu-toggle pull-right" data-target="#sitemap-8" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle menu</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="sitemap-section-body panel-body collapsable collapse" id="sitemap-8">
# <ul class="list-unstyled">
# <li><a href="http://weather.gov/owlie">NWS Education Home</a></li>
# <li><a href="http://www.nws.noaa.gov/com/weatherreadynation/force.html">Be A Force of Nature</a></li>
# <li><a href=" http://www.education.noaa.gov/Weather_and_Atmosphere/">NOAA Education Resources </a></li>
# <li><a href=" http://www.weather.gov/glossary/">Glossary </a></li>
# <li><a href="https://www.weather.gov/jetstream/">JetStream </a></li>
# <li><a href=" http://www.weather.gov/training/">NWS Training Portal </a></li>
# <li><a href="https://library.noaa.gov/">NOAA Library </a></li>
# <li><a href="http://weather.gov/owlie">For Students, Parents and Teachers</a></li>
# <li><a href="http://www.weather.gov/owlie/publication_brochures">Brochures </a></li>
# </ul>
# </div>
# </div>
# <div class="sitemap-section">
# <div class="panel-heading">
# <a class="sitemap-section-heading" href="http://weather.gov/about">ABOUT</a>
# <button class="menu-toggle pull-right" data-target="#sitemap-9" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle menu</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="sitemap-section-body panel-body collapsable collapse" id="sitemap-9">
# <ul class="list-unstyled">
# <li><a href="http://weather.gov/organization">Organization </a></li>
# <li><a href="https://www.weather.gov/media/wrn/NWS_Weather-Ready-Nation_Strategic_Plan_2019-2022.pdf">Strategic Plan </a></li>
# <li><a href="https://sites.google.com/a/noaa.gov/nws-best-practices/">For NWS Employees </a></li>
# <li><a href="https://www.weather.gov/international/">International </a></li>
# <li><a href="http://www.ncep.noaa.gov/">National Centers </a></li>
# <li><a href=" http://www.weather.gov/tg/">Products and Services </a></li>
# <li><a href="http://www.weather.gov/careers/">Careers</a></li>
# <li><a href=" http://www.weather.gov/glossary/">Glossary </a></li>
# <li><a href="http://weather.gov/contact">Contact Us </a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- legal footer area -->
# <div class="footer-legal">
# <div class="col-xs-12 col-sm-2 col-md-2" id="footerLogo">
# <a href="http://www.usa.gov"><img alt="usa.gov" height="30" src="/css/images/usa_gov.png" width="110"/></a>
# </div>
# <div class="col-xs-12 col-sm-4 col-md-4">
# <ul class="list-unstyled footer-legal-content">
# <li><a href="http://www.commerce.gov">US Dept of Commerce</a></li>
# <li><a href="http://www.noaa.gov">National Oceanic and Atmospheric Administration</a></li>
# <li><a href="http://www.weather.gov">National Weather Service</a></li>
# <li><a href="https://www.weather.gov/mtr">San Francisco Bay Area, CA</a></li><li><br><a href="mailto:w-mtr.webmaster@noaa.gov">Comments? Questions? Please Contact Us.</a></br></li> </ul>
# </div>
# <div class="col-xs-12 col-sm-3 col-md-3">
# <ul class="list-unstyled">
# <li><a href="https://www.weather.gov/disclaimer">Disclaimer</a></li>
# <li><a href="http://www.cio.noaa.gov/services_programs/info_quality.html">Information Quality</a></li>
# <li><a href="https://www.weather.gov/help">Help</a></li>
# <li><a href="http://www.weather.gov/glossary">Glossary</a></li>
# </ul>
# </div>
# <div class="col-xs-12 col-sm-3 col-md-3">
# <ul class="list-unstyled">
# <li><a href="https://www.weather.gov/privacy">Privacy Policy</a></li>
# <li><a href="https://www.noaa.gov/foia-freedom-of-information-act">Freedom of Information Act (FOIA)</a></li>
# <li><a href="https://www.weather.gov/about">About Us</a></li>
# <li><a href="https://www.weather.gov/careers">Career Opportunities</a></li>
# </ul>
# </div>
# </div>
# </footer>

# %%
# sevenDays = soup.select("#seven-day-forecast")
sevenDays = soup.find(id="seven-day-forecast")
sevenDays
# Out:
# <div class="panel panel-default" id="seven-day-forecast">
# <div class="panel-heading">
# <b>Extended Forecast for</b>
# <h2 class="panel-title">
# 	    	    San Francisco CA	</h2>
# </div>
# <div class="panel-body" id="seven-day-forecast-body">
# <div id="seven-day-forecast-container"><div id="headline-container"><div id="headline-info" onclick="$('#headline-detail').toggle(); $('#headline-detail-now').hide()" style="margin-top: 5px"><div id="headline-detail"><div>Heat Advisory October 1, 11:00am until October 1, 08:00pm</div></div><span class="fa fa-info-circle"></span>Click here for hazard details and duration</div><div class="headline-bar headline-advisory " style="top: 40px; left: 176px; height: 125px; width: 93px">
# <div class="headline-title">Heat Advisory</div>
# </div></div><ul class="list-unstyled" id="seven-day-forecast-list" style="padding-top: 60px"><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Overnight<br/><br/></p>
# <p><img alt="Overnight: Widespread haze. Patchy smoke. Partly cloudy, with a low around 60. West southwest wind around 7 mph. " class="forecast-icon" src="newimages/medium/hz.png" title="Overnight: Widespread haze. Patchy smoke. Partly cloudy, with a low around 60. West southwest wind around 7 mph. "/></p><p class="short-desc">Haze</p><p class="temp temp-low">Low: 60 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Thursday<br/><br/></p>
# <p><img alt="Thursday: Widespread haze before 9am. Patchy smoke before 9am. Sunny, with a high near 92. Light southwest wind becoming west 5 to 10 mph in the afternoon. " class="forecast-icon" src="DualImage.php?i=hz&amp;j=few" title="Thursday: Widespread haze before 9am. Patchy smoke before 9am. Sunny, with a high near 92. Light southwest wind becoming west 5 to 10 mph in the afternoon. "/></p><p class="short-desc">Haze then<br/>Sunny</p><p class="temp temp-high">High: 92 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Thursday<br/>Night</p>
# <p><img alt="Thursday Night: Mostly clear, with a low around 62. West wind 8 to 13 mph. " class="forecast-icon" src="newimages/medium/nfew.png" title="Thursday Night: Mostly clear, with a low around 62. West wind 8 to 13 mph. "/></p><p class="short-desc">Mostly Clear</p><p class="temp temp-low">Low: 62 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Friday<br/><br/></p>
# <p><img alt="Friday: Sunny, with a high near 82. West wind 5 to 15 mph, with gusts as high as 18 mph. " class="forecast-icon" src="newimages/medium/few.png" title="Friday: Sunny, with a high near 82. West wind 5 to 15 mph, with gusts as high as 18 mph. "/></p><p class="short-desc">Sunny</p><p class="temp temp-high">High: 82 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Friday<br/>Night</p>
# <p><img alt="Friday Night: Mostly clear, with a low around 59. West wind 11 to 15 mph, with gusts as high as 20 mph. " class="forecast-icon" src="newimages/medium/nfew.png" title="Friday Night: Mostly clear, with a low around 59. West wind 11 to 15 mph, with gusts as high as 20 mph. "/></p><p class="short-desc">Mostly Clear</p><p class="temp temp-low">Low: 59 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Saturday<br/><br/></p>
# <p><img alt="Saturday: Mostly sunny, with a high near 74." class="forecast-icon" src="newimages/medium/sct.png" title="Saturday: Mostly sunny, with a high near 74."/></p><p class="short-desc">Mostly Sunny</p><p class="temp temp-high">High: 74 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Saturday<br/>Night</p>
# <p><img alt="Saturday Night: Mostly cloudy, with a low around 57." class="forecast-icon" src="newimages/medium/nbkn.png" title="Saturday Night: Mostly cloudy, with a low around 57."/></p><p class="short-desc">Mostly Cloudy</p><p class="temp temp-low">Low: 57 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Sunday<br/><br/></p>
# <p><img alt="Sunday: Partly sunny, with a high near 70." class="forecast-icon" src="newimages/medium/bkn.png" title="Sunday: Partly sunny, with a high near 70."/></p><p class="short-desc">Partly Sunny</p><p class="temp temp-high">High: 70 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Sunday<br/>Night</p>
# <p><img alt="Sunday Night: Mostly cloudy, with a low around 57." class="forecast-icon" src="newimages/medium/nbkn.png" title="Sunday Night: Mostly cloudy, with a low around 57."/></p><p class="short-desc">Mostly Cloudy</p><p class="temp temp-low">Low: 57 °F</p></div></li></ul></div>
# <script type="text/javascript">
# // equalize forecast heights
# $(function () {
# 	var maxh = 0;
# 	$(".forecast-tombstone .short-desc").each(function () {
# 		var h = $(this).height();
# 		if (h > maxh) { maxh = h; }
# 	});
# 	$(".forecast-tombstone .short-desc").height(maxh);
# });
# </script> </div>
# </div>

# %%
forecast = sevenDays.find_all(class_ = 'tombstone-container')

# %%
period = forecast[0].find(class_ = 'period-name').get_text()
period
# Out:
# 'Overnight'

# %%
short_desc = forecast[0].find(class_ = 'short-desc').get_text()
short_desc
# Out:
# 'Haze'

# %%
img = forecast[0].find('img')
img_src = img['src']
img_src
# Out:
# 'newimages/medium/hz.png'

# %%
sevenDays = soup.select("#seven-day-forecast")

# %% [markdown]
# ## 필요한 기상정보 전체를 가져오기

# %%
sevenDays = soup.find(id="seven-day-forecast")
sevenDays
# Out:
# <div class="panel panel-default" id="seven-day-forecast">
# <div class="panel-heading">
# <b>Extended Forecast for</b>
# <h2 class="panel-title">
# 	    	    San Francisco CA	</h2>
# </div>
# <div class="panel-body" id="seven-day-forecast-body">
# <div id="seven-day-forecast-container"><div id="headline-container"><div id="headline-info" onclick="$('#headline-detail').toggle(); $('#headline-detail-now').hide()" style="margin-top: 5px"><div id="headline-detail"><div>Heat Advisory October 1, 11:00am until October 1, 08:00pm</div></div><span class="fa fa-info-circle"></span>Click here for hazard details and duration</div><div class="headline-bar headline-advisory " style="top: 40px; left: 176px; height: 125px; width: 93px">
# <div class="headline-title">Heat Advisory</div>
# </div></div><ul class="list-unstyled" id="seven-day-forecast-list" style="padding-top: 60px"><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Overnight<br/><br/></p>
# <p><img alt="Overnight: Widespread haze. Patchy smoke. Partly cloudy, with a low around 60. West southwest wind around 7 mph. " class="forecast-icon" src="newimages/medium/hz.png" title="Overnight: Widespread haze. Patchy smoke. Partly cloudy, with a low around 60. West southwest wind around 7 mph. "/></p><p class="short-desc">Haze</p><p class="temp temp-low">Low: 60 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Thursday<br/><br/></p>
# <p><img alt="Thursday: Widespread haze before 9am. Patchy smoke before 9am. Sunny, with a high near 92. Light southwest wind becoming west 5 to 10 mph in the afternoon. " class="forecast-icon" src="DualImage.php?i=hz&amp;j=few" title="Thursday: Widespread haze before 9am. Patchy smoke before 9am. Sunny, with a high near 92. Light southwest wind becoming west 5 to 10 mph in the afternoon. "/></p><p class="short-desc">Haze then<br/>Sunny</p><p class="temp temp-high">High: 92 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Thursday<br/>Night</p>
# <p><img alt="Thursday Night: Mostly clear, with a low around 62. West wind 8 to 13 mph. " class="forecast-icon" src="newimages/medium/nfew.png" title="Thursday Night: Mostly clear, with a low around 62. West wind 8 to 13 mph. "/></p><p class="short-desc">Mostly Clear</p><p class="temp temp-low">Low: 62 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Friday<br/><br/></p>
# <p><img alt="Friday: Sunny, with a high near 82. West wind 5 to 15 mph, with gusts as high as 18 mph. " class="forecast-icon" src="newimages/medium/few.png" title="Friday: Sunny, with a high near 82. West wind 5 to 15 mph, with gusts as high as 18 mph. "/></p><p class="short-desc">Sunny</p><p class="temp temp-high">High: 82 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Friday<br/>Night</p>
# <p><img alt="Friday Night: Mostly clear, with a low around 59. West wind 11 to 15 mph, with gusts as high as 20 mph. " class="forecast-icon" src="newimages/medium/nfew.png" title="Friday Night: Mostly clear, with a low around 59. West wind 11 to 15 mph, with gusts as high as 20 mph. "/></p><p class="short-desc">Mostly Clear</p><p class="temp temp-low">Low: 59 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Saturday<br/><br/></p>
# <p><img alt="Saturday: Mostly sunny, with a high near 74." class="forecast-icon" src="newimages/medium/sct.png" title="Saturday: Mostly sunny, with a high near 74."/></p><p class="short-desc">Mostly Sunny</p><p class="temp temp-high">High: 74 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Saturday<br/>Night</p>
# <p><img alt="Saturday Night: Mostly cloudy, with a low around 57." class="forecast-icon" src="newimages/medium/nbkn.png" title="Saturday Night: Mostly cloudy, with a low around 57."/></p><p class="short-desc">Mostly Cloudy</p><p class="temp temp-low">Low: 57 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Sunday<br/><br/></p>
# <p><img alt="Sunday: Partly sunny, with a high near 70." class="forecast-icon" src="newimages/medium/bkn.png" title="Sunday: Partly sunny, with a high near 70."/></p><p class="short-desc">Partly Sunny</p><p class="temp temp-high">High: 70 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Sunday<br/>Night</p>
# <p><img alt="Sunday Night: Mostly cloudy, with a low around 57." class="forecast-icon" src="newimages/medium/nbkn.png" title="Sunday Night: Mostly cloudy, with a low around 57."/></p><p class="short-desc">Mostly Cloudy</p><p class="temp temp-low">Low: 57 °F</p></div></li></ul></div>
# <script type="text/javascript">
# // equalize forecast heights
# $(function () {
# 	var maxh = 0;
# 	$(".forecast-tombstone .short-desc").each(function () {
# 		var h = $(this).height();
# 		if (h > maxh) { maxh = h; }
# 	});
# 	$(".forecast-tombstone .short-desc").height(maxh);
# });
# </script> </div>
# </div>

# %%
sevenDays = soup.find(id="seven-day-forecast")
periods = sevenDays.select('.tombstone-container .period-name')
periods
# Out:
# [<p class="period-name">Overnight<br/><br/></p>,
#  <p class="period-name">Thursday<br/><br/></p>,
#  <p class="period-name">Thursday<br/>Night</p>,
#  <p class="period-name">Friday<br/><br/></p>,
#  <p class="period-name">Friday<br/>Night</p>,
#  <p class="period-name">Saturday<br/><br/></p>,
#  <p class="period-name">Saturday<br/>Night</p>,
#  <p class="period-name">Sunday<br/><br/></p>,
#  <p class="period-name">Sunday<br/>Night</p>]

# %%
periods_text = [text.get_text() for text in periods ]
periods_text
# Out:
# ['Overnight',
#  'Thursday',
#  'ThursdayNight',
#  'Friday',
#  'FridayNight',
#  'Saturday',
#  'SaturdayNight',
#  'Sunday',
#  'SundayNight']

# %%
descs = sevenDays.select('.tombstone-container .short-desc')
descs
# Out:
# [<p class="short-desc">Haze</p>,
#  <p class="short-desc">Haze then<br/>Sunny</p>,
#  <p class="short-desc">Mostly Clear</p>,
#  <p class="short-desc">Sunny</p>,
#  <p class="short-desc">Mostly Clear</p>,
#  <p class="short-desc">Mostly Sunny</p>,
#  <p class="short-desc">Mostly Cloudy</p>,
#  <p class="short-desc">Partly Sunny</p>,
#  <p class="short-desc">Mostly Cloudy</p>]

# %%
desc_text = [text.get_text() for text in descs ]
desc_text
# Out:
# ['Haze',
#  'Haze thenSunny',
#  'Mostly Clear',
#  'Sunny',
#  'Mostly Clear',
#  'Mostly Sunny',
#  'Mostly Cloudy',
#  'Partly Sunny',
#  'Mostly Cloudy']

# %%
temp_text = [text.get_text() for text in sevenDays.select('.tombstone-container .temp')]
temp_text
# Out:
# ['Low: 60 °F',
#  'High: 92 °F',
#  'Low: 62 °F',
#  'High: 82 °F',
#  'Low: 59 °F',
#  'High: 74 °F',
#  'Low: 57 °F',
#  'High: 70 °F',
#  'Low: 57 °F']

# %%
# temp_text.append('High: 77 °F')
print(len(periods_text))
print(len(desc_text))
print(len(temp_text))
# -> 8이라서 테이블을 만들 수 없으므로 temp_text에 append 해줌
# Out:
# 9
# 9
# 9

# %% [markdown]
# #### 테이블을 만드려면 length 체크를 해주는 것이 좋다

# %%
import pandas as pd

# %%
forecast_df = pd.DataFrame({
    'period' : periods_text,
    'desc'   : desc_text,
    'temp'   : temp_text
})

# %%
forecast_df
# Out:
#           period            desc         temp
# 0      Overnight            Haze   Low: 60 °F
# 1       Thursday  Haze thenSunny  High: 92 °F
# 2  ThursdayNight    Mostly Clear   Low: 62 °F
# 3         Friday           Sunny  High: 82 °F
# 4    FridayNight    Mostly Clear   Low: 59 °F
# 5       Saturday    Mostly Sunny  High: 74 °F
# 6  SaturdayNight   Mostly Cloudy   Low: 57 °F
# 7         Sunday    Partly Sunny  High: 70 °F
# 8    SundayNight   Mostly Cloudy   Low: 57 °F

# %%
forecast_df.to_csv('forecast_df.csv' , mode='w' , encoding='utf-8')
print('success')
# Out:
# success
